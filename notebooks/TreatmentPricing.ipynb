# %%
import json

# %%
from sqlalchemy import create_engine

# %%
# Connect to DB
engine = create_engine('postgresql://meditreats:meditreats@df-treats-db.cs6hxh6ocizm.us-west-2.rds.amazonaws.com:5432/meditreats')
connection = engine.connect()

# %%
from collections import defaultdict

# %%
query = '''SELECT 
   table_name, 
   column_name, 
   data_type 
FROM 
   information_schema.columns
WHERE 
   table_name = \'conditions\''''
[print(row)  for row in engine.execute(query)]
# Out:
# ('conditions', 'id', 'integer')
# ('conditions', 'name', 'character varying')
# ('conditions', 'condition_group', 'integer')
# [None, None, None]

# %%
import pandas as pd

# %%
result = engine.execute('SELECT * FROM treatments WHERE from_study=True')

# Grab table
df = pd.read_sql('SELECT * FROM conditions', engine)
# Out:
#          id                                               name condition_group
# 0        64                          Major Depressive Disorder            None
# 1        65                                             Asthma            None
# 2         0                             Neuromuscular Blockade            None
# 3         8                          Diabetes Mellitus, Type 2            None
# 4        81                                        Hypersomnia            None
# ...     ...                                                ...             ...
# 10603  1576                                   Infant Mortality            None
# 10604  1581       Untreated Adult Acute Lymphoblastic Leukemia            None
# 10605  1604             Stage IIA Breast Cancer AJCC v6 and v7            None
# 10606  1627                            Hypertensive Anal Canal            None
# 10607  1630  Patients With Advanced Ovarian Cancer Sensitiv...            None
#
# ...

# %%
df
# Out:
#          id                                               name condition_group
# 0        64                          Major Depressive Disorder            None
# 1        65                                             Asthma            None
# 2         0                             Neuromuscular Blockade            None
# 3         8                          Diabetes Mellitus, Type 2            None
# 4        81                                        Hypersomnia            None
# ...     ...                                                ...             ...
# 10603  1576                                   Infant Mortality            None
# 10604  1581       Untreated Adult Acute Lymphoblastic Leukemia            None
# 10605  1604             Stage IIA Breast Cancer AJCC v6 and v7            None
# 10606  1627                            Hypertensive Anal Canal            None
# 10607  1630  Patients With Advanced Ovarian Cancer Sensitiv...            None
#
# ...

# %%
group_to_id = defaultdict(def_value)
for condition in data.keys():
    id = df[df['name']== condition]['id']
    if len(id) != 0:
        group_to_id[condition] = int(id)

# %%
successful_groupings = set()

# %%
from sqlalchemy import sql

# %%
# Grouped
for i, row in df.iterrows():
    condition_group = inverted[row['name']]
    group_id = group_to_id[condition_group]
    if condition_group and group_id:
        df.at[i,'condition_group'] = group_id 
        if group_id not in successful_groupings:
            query = 'INSERT INTO condition_groups (id, name) VALUES (%s, %s)'
            engine.execute(query, (group_id, condition_group))
            successful_groupings.add(group_id)
        query = 'UPDATE conditions set condition_group={} where id={}'.format(group_id, row['id'])
        print(query)
        engine.execute(query)
# Ungrouped
for i, row in df.iterrows():
    condition_group = inverted[row['name']]
    group_id = group_to_id[condition_group
    else:
        # No grouping
        if row['id'] not in successful_groupings:
            query = 'INSERT INTO condition_groups (id, name) VALUES (%s, %s)'
            print(query)
            engine.execute(query, (row['id'], row['name']))
            successful_groupings.add(row['id'])
        query = 'UPDATE conditions set condition_group={} where id={}'.format(row['id'], row['id'])
        print(query)
        engine.execute(query)
# print(successful_groupings)
# Out:
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=0 where id=0
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=8 where id=8
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=81 where id=81
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=82 where id=82
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=83 where id=83
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=84 where id=84
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=85 where id=85
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# UPDATE conditions set condition_group=86 where id=86
# INSERT INTO condition_groups (id, name) VALUES (%s, %s)
# ...

# %%
result = engine.execute('SELECT * FROM condition_groups')
len(result)

# %%
len(successful_groupings)
# Out:
# 10453

# %%
# Clear clusters

query = 'UPDATE conditions set condition_group={}'.format(sql.null())
engine.execute(query)

result = engine.execute('SELECT * FROM condition_groups')
for row in result:
    engine.execute('DELETE from condition_groups WHERE id={}'.format(row['id']))
    print(row)

# %%
df.loc[df['name'] =='Depression']
# Out:
#       id        name condition_group
# 345  345  Depression            None

# %%
conditions_db = df.copy(deep=True)

# %%
conditions_db.loc[df['name'] =='Depression']
# Out:
#       id        name condition_group
# 345  345  Depression            None
