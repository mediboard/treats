# %%
import pandas as pd
import numpy as np
import torch

# %%
studies_table_0 = pd.read_pickle('int_new_studies_0.pkl').reset_index(drop=True)
studies_table_1 = pd.read_pickle('int_new_studies_1.pkl').reset_index(drop=True)
studies_table_2 = pd.read_pickle('int_new_studies_2.pkl').reset_index(drop=True)

studies_table = pd.concat([studies_table_0, studies_table_1, studies_table_2]).reset_index(drop=True)

# %%
studies_table
# Out:
#           study_id                                     official_title  \
# 0      NCT03266419  A Double-blind, Randomized, Parallel Design to...
# 1      NCT03262441  Mycophenolate Mofetil Therapy for Reduction of...
# 2      NCT03260894  A Randomized, Open-Label, Phase 3 Study to Eva...
# 3      NCT03267940  A Phase 1B, Randomized, Open-Label Study of PE...
# 4      NCT03264157  A Prospective, Randomized, Double-Blind Parall...
# ...            ...                                                ...
# 28090  NCT03035708  Human Laboratory Study of Varenicline for Alco...
# 28091  NCT03034772  A Randomized Controlled Trial Comparing the Ef...
# 28092  NCT03030989  A Double-blind Randomized Placebo Controlled C...
# 28093  NCT03038880  STAIRWAY: Simultaneous Blockade of Angiopoieti...
# 28094  NCT03031496  An Open-label, Randomized, Single-dose, Two-pe...
#
#                                              short_title  \
# 0      Effectiveness of Deep Versus Moderate Neuromus...
# 1                        MMF for HIV Reservoir Reduction
# 2      Pembrolizumab (MK-3475) Plus Epacadostat vs St...
# 3      Study of PEGPH20 With Cisplatin (CIS) and Gemc...
# 4      Safety and Effectiveness of BPL HRIG With Acti...
# ...                                                  ...
# 28090  Human Laboratory Study of Varenicline for Alco...
# 28091  Dorzolamide-timolol in Combination With Anti-v...
# 28092  A Double-blind Randomized Placebo Controlled C...
# 28093  Study to Evaluate Faricimab (RO6867461; RG7716...
# 28094  Bioequivalence Study Between GSK3542503 Hydroc...
#
#                                               conditions  verified_date  \
# 0                               [Neuromuscular Blockade]   October 2019
# 1             [Human Immunodeficiency Virus I Infection]  November 2020
# 2                           [Renal Cell Carcinoma (RCC)]    August 2020
# 3      [Cholangiocarcinoma Non-resectable, Cholangioc...   January 2020
# 4                                              [Healthy]   January 2020
# ...                                                  ...            ...
# 28090                             [Alcohol Use Disorder]   October 2019
# 28091  [Neovascular Age-related Macular Degeneration,...      June 2020
# 28092               [Stem Cell Transplant Complications]  November 2020
# 28093  [Neovascularization, Choroidal, Macular Degene...  December 2020
# 28094                                     [Hypertension]     April 2018
#
#       responsible_party                                            sponsor  \
# 0       Byung-Moon Choi                                Asan Medical Center
# 1       Joshua Schiffer             Fred Hutchinson Cancer Research Center
# 2                    NA                                 Incyte Corporation
# 3                    NA                              Halozyme Therapeutics
# 4                    NA                            Bio Products Laboratory
# ...                 ...                                                ...
# 28090                NA  National Institute on Alcohol Abuse and Alcoho...
# 28091     Jason Hsu, MD                                          Wills Eye
# 28092                NA                              University of Chicago
# 28093                NA                                  Hoffmann-La Roche
# 28094                NA                                    GlaxoSmithKline
#
#                  type                                        description  \
# 0      Interventional  The aim of this study is to evaluate the influ...
# 1      Interventional  This is an open label, randomized Phase II stu...
# 2      Interventional  The purpose of this study was to evaluate the ...
# 3      Interventional  The study is being conducted to assess the saf...
# 4      Interventional  A prospective, randomized, blinded, parallel-g...
# ...               ...                                                ...
# 28090  Interventional  This study is a double-blind, randomized, plac...
# 28091  Interventional  A previous pilot study demonstrated that commo...
# 28092  Interventional  This study evaluates the use of 2% CHG washclo...
# 28093  Interventional  This was a Phase II, multicenter, randomized, ...
# 28094  Interventional  The combination of the diuretics amiloride hyd...
#
#                                            interventions     purpose  \
# 0                                           [Rocuronium]   Treatment
# 1                                    [Mycophenolic Acid]   Treatment
# 2                             [Pembrolizumab, Sunitinib]   Treatment
# 3                                         [Atezolizumab]   Treatment
# 4                                             [Vaccines]   Treatment
# ...                                                  ...         ...
# 28090                                      [Varenicline]   Treatment
# 28091        [Timolol, Dorzolamide, Lubricant Eye Drops]   Treatment
# 28092           [Chlorhexidine, Chlorhexidine gluconate]  Prevention
# 28093                                      [Ranibizumab]   Treatment
# 28094  [Hydrochlorothiazide, Amiloride, Amiloride, hy...   Treatment
#
#              intervention_type  \
# 0          Parallel Assignment
# 1      Single Group Assignment
# 2          Parallel Assignment
# 3        Sequential Assignment
# 4          Parallel Assignment
# ...                        ...
# 28090      Parallel Assignment
# 28091      Parallel Assignment
# 28092      Parallel Assignment
# 28093      Parallel Assignment
# 28094     Crossover Assignment
#
#                                               mesh_terms  \
# 0                                                     []
# 1      [Acquired Immunodeficiency Syndrome, HIV Infec...
# 2                     [Carcinoma, Carcinoma, Renal Cell]
# 3                   [Adenocarcinoma, Cholangiocarcinoma]
# 4                                               [Rabies]
# ...                                                  ...
# 28090                     [Alcoholism, Alcohol Drinking]
# 28091   [Macular Degeneration, Wet Macular Degeneration]
# 28092                                        [Infection]
# 28093  [Macular Degeneration, Choroidal Neovasculariz...
# 28094                                     [Hypertension]
#
#                                                 criteria   min_age   max_age  \
# 0      Inclusion Criteria:\n\nPatients 20 to 65 years...  20 Years  65 Years
# 1      Inclusion Criteria:\n\nConfirmed HIV infection...  18 Years  65 Years
# 2      Inclusion Criteria:\n\nHistologic confirmation...  18 Years        NA
# 3      Inclusion Criteria:\n\nFor both portions of th...  18 Years        NA
# 4      Inclusion Criteria:\n\nAble and willing to sig...  18 Years  75 Years
# ...                                                  ...       ...       ...
# 28090  Inclusion Criteria:\n\nTo be eligible, the sub...  21 Years        NA
# 28091  Inclusion Criteria:\n\nActive choroidal neovas...  45 Years        NA
# 28092  Inclusion Criteria:\n\nAdmitted to the Univers...  18 Years        NA
# 28093  Inclusion Criteria\n\nTreatment-naive CNV seco...  50 Years        NA
# 28094  Inclusion Criteria:\n\nParticipants must be be...  18 Years  65 Years
#
#       gender
# 0        All
# 1        All
# 2        All
# 3        All
# 4        All
# ...      ...
# 28090    All
# 28091    All
# 28092    All
# 28093    All
# 28094    All
#
# [28095 rows x 17 columns]

# %%
def create_base_measurements(studies):
    df = {
        'study': [],
        'group_id': [],
        'base': [],
        'class': [],
        'category': [],
        'param_type': [],
        'dispersion_type': [],
        'unit': [],
        'value': [],
        'spread': [],
        'upper': [],
        'lower': []
    }
    for study in studies:
        study_id = study['Study']['ProtocolSection']['IdentificationModule']['NCTId']
        measures = study['Study']['ResultsSection']['BaselineCharacteristicsModule'].get('BaselineMeasureList', {'BaselineMeasure': []})['BaselineMeasure']

        for measure in measures:
            classes = measure.get('BaselineClassList', {'BaselineClass': []})['BaselineClass']

            for clss in classes:
                categories = clss.get('BaselineCategoryList', {'BaselineCategory': []})['BaselineCategory']

                for category in categories:
                    measurements = category.get('BaselineMeasurementList', {'BaselineMeasurement': []})['BaselineMeasurement']
                    for measurement in measurements:
                        df['study'].append(study_id)
                        df['group_id'].append(measurement.get('BaselineMeasurementGroupId', 'NA'))
                        df['base'].append(measure.get('BaselineMeasureTitle', 'NA'))
                        df['class'].append(clss.get('BaselineClassTitle', 'NA'))
                        df['category'].append(category.get('BaselineCategoryTitle', 'NA'))
                        df['param_type'].append(measure.get('BaselineMeasureParamType', 'NA'))
                        df['dispersion_type'].append(measure.get('BaselineMeasureDispersionType', 'NA'))
                        df['unit'].append(measure.get('BaselineMeasureUnitOfMeasure', 'NA'))
                        df['value'].append(measurement.get('BaselineMeasurementValue', 'NA'))
                        df['spread'].append(measurement.get('BaselineMeasurementSpread', 'NA'))
                        df['upper'].append(measurement.get('BaselineMeasurementUpperLimit', 'NA'))
                        df['lower'].append(measurement.get('BaselineMeasurementLowerLimit', 'NA'))
    return df

# %%
def create_studies_table(studies):
    buffer = {
        'study_id': [], 'official_title': [], 'short_title':[], 'conditions': [], 
        'verified_date': [], 'responsible_party': [], 'sponsor':[], 'type': [], 'description': [],
        'interventions': [], 'purpose': [], 'intervention_type': [], 'mesh_terms': [],
        'criteria': [], 'min_age': [], 'max_age': [], 'gender': []}
    for i, study in enumerate(studies):


        try:
            buffer['study_id'].append(study['Study']['ProtocolSection']['IdentificationModule']['NCTId'])
        except KeyError as e:
            buffer['study_id'].append('NA')

        try:
            buffer['official_title'].append(study['Study']['ProtocolSection']['IdentificationModule']['OfficialTitle'])
        except KeyError as e:
            buffer['official_title'].append('NA')
            
        try:
            buffer['short_title'].append(study['Study']['ProtocolSection']['IdentificationModule']['BriefTitle'])
        except KeyError as e:
            buffer['short_title'].append('NA')

        try:
            buffer['verified_date'].append(study['Study']['ProtocolSection']['StatusModule']['StatusVerifiedDate'])
        except KeryError as e:
            buffer['verified_date'].append('NA')

        try:
            buffer['responsible_party'].append(study['Study']['ProtocolSection']['SponsorCollaboratorsModule']['ResponsibleParty']['ResponsiblePartyInvestigatorFullName'])
        except KeyError as e:
            buffer['responsible_party'].append('NA')
            
        try:
            buffer['sponsor'].append(study['Study']['ProtocolSection']['SponsorCollaboratorsModule']['LeadSponsor']['LeadSponsorName'])
        except KeyError as e:
            buffer['sponsor'].append('NA')

        try: 
            buffer['conditions'].append(study['Study']['ProtocolSection']['ConditionsModule']['ConditionList']['Condition'])
        except KeyError as e:
            buffer['conditions'].append('NA')

        try:
            buffer['type'].append(study['Study']['ProtocolSection']['DesignModule']['StudyType'])
        except KeyError as e:
            buffer['type'].append('NA')
        
        try:
            buffer['purpose'].append(study['Study']['ProtocolSection']['DesignModule']['DesignInfo'].get('DesignPrimaryPurpose', 'NA'))
        except KeyError as e:
            buffer['purpose'].append('NA')
            
        try:
            buffer['intervention_type'].append(study['Study']['ProtocolSection']['DesignModule']['DesignInfo'].get('DesignInterventionModel', 'NA'))
        except KeyError as e:
            buffer['intervention_type'].append('NA')
        
        try:
            buffer['mesh_terms'].append([x.get('ConditionMeshTerm', 'NA') for x in study['Study']['DerivedSection']['ConditionBrowseModule']['ConditionMeshList']['ConditionMesh']])
        except KeyError as e:
            buffer['mesh_terms'].append([])
            
        try:
            buffer['description'].append(study['Study']['ProtocolSection']['DescriptionModule']['BriefSummary'])
        except KeyError as e:
            buffer['description'].append('NA')
            
        try: 
            buffer['interventions'].append([x.get('InterventionMeshTerm', 'NA') for x in study['Study']['DerivedSection']['InterventionBrowseModule']['InterventionMeshList']['InterventionMesh']])
        except KeyError as e:
            buffer['interventions'].append([])
            
        try:
            buffer['criteria'].append(study['Study']['ProtocolSection']['EligibilityModule']['EligibilityCriteria'])
        except KeyError as e:
            buffer['criteria'].append('NA')
            
        try:
            buffer['gender'].append(study['Study']['ProtocolSection']['EligibilityModule']['Gender'])
        except KeyError as e:
            buffer['gender'].append('NA')
        
        try:
            buffer['min_age'].append(study['Study']['ProtocolSection']['EligibilityModule']['MinimumAge'])
        except KeyError as e:
            buffer['min_age'].append('NA')
            
        try:
            buffer['max_age'].append(study['Study']['ProtocolSection']['EligibilityModule']['MaximumAge'])
        except KeyError as e:
            buffer['max_age'].append('NA')
    return buffer

# %%
def create_effects_table(studies):
    df = {
        'study_id': [],
        'group_id': [],
        'effect_name': [],
        'type': [], #Serious or other
        'organ_system': [],
        'assesment': [],
        'no_effected': [],
        'collection_threshold': [],
        'no_at_risk':[]
    }
    for i, study in enumerate(studies):
        study_id = study['Study']['ProtocolSection']['IdentificationModule']['NCTId']
        adverse_module = study['Study']['ResultsSection'].get('AdverseEventsModule', {}) #Small risk here
        for event in adverse_module.get('OtherEventList', {'OtherEvent': []})['OtherEvent']:
            for stat in event.get('OtherEventStatsList', {'OtherEventStats': []})['OtherEventStats']:
                df['study_id'].append(study_id)
                df['group_id'].append(stat.get('OtherEventStatsGroupId', 'NA'))
                df['effect_name'].append(event.get('OtherEventTerm', 'NA'))
                df['type'].append('other')
                df['organ_system'].append(event.get('OtherEventOrganSystem', 'NA'))
                df['assesment'].append(event.get('OtherEventAssessmentType', 'NA'))
                df['no_effected'].append(float(stat.get('OtherEventStatsNumAffected', 0)) or float(stat.get('OtherEventStatsNumEvents', 0)))
                df['collection_threshold'].append(float(adverse_module.get('EventsFrequencyThreshold', -1)))
                df['no_at_risk'].append(int(stat.get('OtherEventStatsNumAtRisk', -1)))
        for event in adverse_module.get('SeriousEventList', {'SeriousEvent': []})['SeriousEvent']:
            for stat in event.get('SeriousEventStatsList', {'SeriousEventStats': []})['SeriousEventStats']:
                df['study_id'].append(study_id)
                df['group_id'].append(stat.get('SeriousEventStatsGroupId', 'NA'))
                df['effect_name'].append(event.get('SeriousEventTerm', 'NA'))
                df['type'].append('serious')
                df['organ_system'].append(event.get('SeriousEventOrganSystem', 'NA'))
                df['assesment'].append(event.get('SeriousEventAssessmentType', 'NA'))
                df['no_effected'].append(float(stat.get('SeriousEventStatsNumAffected', 0)) or float(stat.get('OtherEventStatsNumEvents', 0)))
                df['collection_threshold'].append(float(adverse_module.get('EventsFrequencyThreshold', -1)))
                df['no_at_risk'].append(int(stat.get('SeriousEventStatsNumAtRisk', -1)))

    return df

# %%
def create_effects_groups_table(studies):
    df = {
        'study_id': [],
        'group_id': [],
        'title': [],
        'description': [], #Serious or other
    }
    for i, study in enumerate(studies):
        study_id = study['Study']['ProtocolSection']['IdentificationModule']['NCTId']
        adverse_module = study['Study']['ResultsSection'].get('AdverseEventsModule', {}) #Small risk here
        for group in adverse_module.get('EventGroupList', {'EventGroup': []})['EventGroup']:
            df['study_id'].append(study_id)
            df['group_id'].append(group.get('EventGroupId', 'NA'))
            df['title'].append(group.get('EventGroupTitle', 'NA'))
            df['description'].append(group.get('EventGroupDescription', 'NA'))
            
    return df

# %%
def get_outcome_modules(studies):
    outcome_modules = []
    for study in studies:
        if 'OutcomeMeasuresModule' in study['Study']['ResultsSection']:
            outcome_modules.append(study['Study']['ResultsSection']['OutcomeMeasuresModule'])
            continue 
        print('No Results: ', study['Study']['ProtocolSection']['IdentificationModule']['OfficialTitle'])
        
    return outcome_modules

def create_outcomes_table(studies):
    outcome_modules = get_outcome_modules(studies)
    admin_df = {
        'study_id': [],
        'group_id': [],
        'measure': [],
        'title': [],
        'description': [],
    }
    
    outcome_df = {
        'study_id': [],
        'group_title': [],
        'group_no': [],
        'measure': [],
        'title': [],
        'value': [],
        'dispersion': [],
        'upper': [],
        'lower': [],
        'participants': []
    }
    
    for i, module in enumerate(outcome_modules):
        study_id = studies[i]['Study']['ProtocolSection']['IdentificationModule']['NCTId']
        for measure in module['OutcomeMeasureList']['OutcomeMeasure']:
            try:
                overall_group_to_no = {}
                for denom in measure.get('OutcomeDenomList', {'OutcomeDenom': []})['OutcomeDenom']:
                    if denom.get('OutcomeDenomUnits', 'NA') == 'Participants':
                        for count in denom.get('OutcomeDenomCountList', {'OutcomeDenomCount': []})['OutcomeDenomCount']:
                            overall_group_to_no[count['OutcomeDenomCountGroupId']] = count['OutcomeDenomCountValue']
                
                group_to_title = {}
                for admin in measure.get('OutcomeGroupList', {'OutcomeGroup': []})['OutcomeGroup']:
                    admin_df['study_id'].append(study_id)
                    admin_df['group_id'].append(admin.get('OutcomeGroupId', 'NA'))
                    admin_df['measure'].append(measure.get('OutcomeMeasureTitle', 'NA'))
                    admin_df['title'].append(admin.get('OutcomeGroupTitle', 'NA'))
                    admin_df['description'].append(admin.get('OutcomeGroupDescription', 'NA'))
                    group_to_title[admin.get('OutcomeGroupId', 'NA')] = admin.get('OutcomeGroupTitle', 'NA')
                    
                # Sometimes the participants are just listed one time before all the others - not just in the class
                for group in measure.get('OutcomeClassList', {'OutcomeClass': []})['OutcomeClass']:
    
                    group_to_no = {}
                    for denom in group.get('OutcomeClassDenomList', {'OutcomeClassDenom': []})['OutcomeClassDenom']:
                        for count in denom.get('OutcomeClassDenomCountList', {'OutcomeClassDenomCount': []})['OutcomeClassDenomCount']:
                            group_to_no[count['OutcomeClassDenomCountGroupId']] = count['OutcomeClassDenomCountValue']

                    for cat in group.get('OutcomeCategoryList', {'OutcomeCategory': []})['OutcomeCategory']:
                        for outcome in cat['OutcomeMeasurementList']['OutcomeMeasurement']:
                            outcome_df['study_id'].append(study_id)
                            outcome_df['group_title'].append(group_to_title[outcome.get('OutcomeMeasurementGroupId', 'NA')])
                            outcome_df['group_no'].append(outcome.get('OutcomeMeasurementGroupId', 'NA'))
                            outcome_df['measure'].append(measure.get('OutcomeMeasureTitle', 'NA'))
                            outcome_df['value'].append(outcome.get('OutcomeMeasurementValue', 'NA'))
                            outcome_df['dispersion'].append(outcome.get('OutcomeMeasurementSpread', 'NA'))
                            outcome_df['upper'].append(outcome.get('OutcomeMeasurementUpperLimit', 'NA'))
                            outcome_df['lower'].append(outcome.get('OutcomeMeasurementLowerLimit', 'NA'))
                            outcome_df['participants'].append(group_to_no.get(outcome.get('OutcomeMeasurementGroupId', 'NA'), None) or overall_group_to_no.get(outcome.get('OutcomeMeasurementGroupId', 'NA'), 'NA'))
                            outcome_df['title'].append(group.get('OutcomeClassTitle', 'NA'))
                        
                    
            except KeyError as e:
                print(e)
                continue
                
    return outcome_df

# %% [markdown]
# ## New Studies

# %%
from os import listdir
from os.path import isfile, join, isdir
import json

def sample_int_studies(no_studies, table_func, table_name):
    # Need to add in MESH terms as a requirement
    study_directories = [f for f in listdir('AllAPIJSON/') if isdir(join('AllAPIJSON/', f))]
    studies = []
    write_counter = 0
    for directory in study_directories:
        studyFileNames = [f for f in listdir('AllAPIJSON/'+directory+'/')]
        for file in studyFileNames:
            try:
                with open('AllAPIJSON/'+directory+'/'+file) as f:
                    data = json.load(f)['FullStudy']
                    has_results = 'ResultsSection' in data['Study'] and 'OutcomeMeasuresModule' in data['Study']['ResultsSection']
                    interventions = [x.get('InterventionMeshTerm', 'NA') for x in data['Study']['DerivedSection']['InterventionBrowseModule']['InterventionMeshList']['InterventionMesh']]
                    conditions = data['Study']['ProtocolSection']['ConditionsModule']['ConditionList']['Condition']
                    study_type = data['Study']['ProtocolSection']['DesignModule']['StudyType']
                    if has_results and interventions and conditions and (study_type == 'Interventional'):
                        studies.append(data)

                    f.close()
                    
                if len(studies) + len(studies)*write_counter >= no_studies:
                    print('writing study', write_counter)
                    table = pd.DataFrame.from_dict(table_func(studies))
                    table.to_pickle('int_'+table_name+'_'+str(write_counter)+'.pkl')
                    studies = []
                    return
                    
                if len(studies) >= 10000:
                    print('writing study', write_counter)
                    table = pd.DataFrame.from_dict(table_func(studies))
                    table.to_pickle('int_'+table_name+'_'+str(write_counter)+'.pkl')
                    write_counter += 1
                    studies = []

            except KeyError: 
                continue

    table = pd.DataFrame.from_dict(table_func(studies))
    table.to_pickle('int_'+table_name+'_'+str(write_counter)+'.pkl')

    write_counter += 1
    studies = []

# %%
sample_int_studies(float('inf'), create_effects_table, 'newer_effects')
# Out:
# writing study 0
# writing study 1

# %% [markdown]
# ## Study Treatments

# %%
# We're going to have to do a direct connection due to the nans in the float column
from sqlalchemy import create_engine

db = create_engine("postgresql://meditreats:meditreats@localhost:5432/meditreats")

# %%
# Load up the conditions from the database
db_treatments = pd.read_csv('meditreats_public_treatments.csv')

# %%
db_treatments.head()
# Out:
#    id              name  from_study  no_studies
# 0   0  Cyclophosphamide        True         678
# 1   1          Vaccines        True         644
# 2   2        Paclitaxel        True         621
# 3   3       Bevacizumab        True         607
# 4   4     Dexamethasone        True         542

# %%
studies_conditions = studies_table[['study_id', 'interventions']].explode('interventions')

# %%
study_treats = studies_conditions.merge(db_treatments[['id', 'name']].rename(columns={
    'name': 'interventions',
    'id': 'treatment'
}), 'left',)[['study_id','treatment']].rename(columns={
    'study_id':'study'
})

# %%
study_treats.to_sql('study_treatments', db, index=False, if_exists='append')

# %% [markdown]
# ## Cleaning Conditions

# %%
conditions = studies_table.explode('conditions')[['conditions','study_id']]

# %%
# Just combine those with the same words for now
import re

conditions['alpha_num'] = conditions['conditions'].apply(lambda x: re.sub(r'[^a-zA-Z0-9 ]', '', x))

# %%
conditions['sorted'] = conditions['alpha_num'].str.split().apply(sorted).apply(tuple)

# %%
conditions_dict = {k:i for i,k in enumerate(conditions['sorted'].unique())}

# %%
import re

def hash_condition(condition):
    return tuple(sorted(re.sub(r'[^a-zA-Z0-9 ]', '', condition).split()))

def most_common(lst):
    return max(set(lst), key=lst.count)

# %%
conditions['condition_id'] = conditions['sorted'].apply(lambda x: conditions_dict[x])

# %%
conditions['l_conditions'] = conditions['conditions'].apply(lambda x: [x])

# %%
conditions_table = pd.DataFrame(conditions.groupby('condition_id')['l_conditions'].apply(sum).apply(most_common))

# %%
conditions_table = conditions_table.set_axis(['name'], axis=1, inplace=False)

# %%
conditions_table = conditions_table.rename_axis(['id'], axis=0)

# %%
study_conditions = conditions[['study_id', 'condition_id']].rename(columns={
    'study_id': 'study',
    'condition_id': 'condition'
}).reset_index(drop=True)

# %%
conditions_table.to_csv('db_int_conditions.csv', header=False)
study_conditions.to_csv('db_int_study_conditions.csv', header=False)

# %%
study_conditions
# Out:
#              study  condition
# 0      NCT03266419          0
# 1      NCT03262441          1
# 2      NCT03260894          2
# 3      NCT03267940          3
# 4      NCT03267940          4
# ...            ...        ...
# 48275  NCT03034772       4407
# 48276  NCT03030989       8836
# 48277  NCT03038880       1313
# 48278  NCT03038880       3414
# 48279  NCT03031496        282
#
# [48280 rows x 2 columns]

# %% [markdown]
# ## Cleaning Treatments

# %%
studies_table
# Out:
#          study_id                                     official_title  \
# 0     NCT03266419  A Double-blind, Randomized, Parallel Design to...
# 1     NCT03262441  Mycophenolate Mofetil Therapy for Reduction of...
# 2     NCT03260894  A Randomized, Open-Label, Phase 3 Study to Eva...
# 3     NCT03267940  A Phase 1B, Randomized, Open-Label Study of PE...
# 4     NCT03264157  A Prospective, Randomized, Double-Blind Parall...
# ...           ...                                                ...
# 9995  NCT02186665  A Multicenter, Randomized, Double Blind, Paral...
# 9996  NCT02184195  A Phase III, Randomised, Double Blind, Placebo...
# 9997  NCT02181790  Addition of 308-nm Excimer Laser to Acitretin ...
# 9998  NCT00265109  Open-Label Study of Levetiracetam in Body Dysm...
# 9999  NCT00265148  Effects of Avandia on Cognition and Cerebral G...
#
#                                             short_title  \
# 0     A Double-blind, Randomized, Parallel Design to...
# 1     Mycophenolate Mofetil Therapy for Reduction of...
# 2     A Randomized, Open-Label, Phase 3 Study to Eva...
# 3     A Phase 1B, Randomized, Open-Label Study of PE...
# 4     A Prospective, Randomized, Double-Blind Parall...
# ...                                                 ...
# 9995  A Multicenter, Randomized, Double Blind, Paral...
# 9996  A Phase III, Randomised, Double Blind, Placebo...
# 9997  Addition of 308-nm Excimer Laser to Acitretin ...
# 9998  Open-Label Study of Levetiracetam in Body Dysm...
# 9999  Effects of Avandia on Cognition and Cerebral G...
#
#                                              conditions  verified_date  \
# 0                              [Neuromuscular Blockade]   October 2019
# 1            [Human Immunodeficiency Virus I Infection]  November 2020
# 2                          [Renal Cell Carcinoma (RCC)]    August 2020
# 3     [Cholangiocarcinoma Non-resectable, Cholangioc...   January 2020
# 4                                             [Healthy]   January 2020
# ...                                                 ...            ...
# 9995                                 [Plaque Psoriasis]     March 2017
# 9996  [Germline BRCA1/2 Mutations and, Metastatic Ad...  November 2020
# 9997                         [Psoriasis, Skin or Nails]  February 2021
# 9998                         [Body Dysmorphic Disorder]    August 2019
# 9999                              [Alzheimer's Disease]   October 2020
#
#      responsible_party                                  sponsor  \
# 0      Byung-Moon Choi                      Asan Medical Center
# 1      Joshua Schiffer   Fred Hutchinson Cancer Research Center
# 2                   NA                       Incyte Corporation
# 3                   NA                    Halozyme Therapeutics
# 4                   NA                  Bio Products Laboratory
# ...                ...                                      ...
# 9995                NA                             Galderma R&D
# 9996                NA                              AstraZeneca
# 9997      Mark Lebwohl  Icahn School of Medicine at Mount Sinai
# 9998                NA                          Butler Hospital
# 9999                NA                          GlaxoSmithKline
#
#                 type                                        description  \
# 0     Interventional  All patients were fasted from midnight without...
# 1     Interventional  This is an open-label, randomized pilot trial ...
# 2     Interventional                                                 NA
# 3     Interventional  The study will have a Run-in portion and an Ex...
# 4     Interventional  Each subject will undergo a total of 9 visits....
# ...              ...                                                ...
# 9995  Interventional                                                 NA
# 9996  Interventional  Approximately 145 patients will be randomised ...
# 9997  Interventional  This open label study evaluated whether a redu...
# 9998  Interventional  Body dysmorphic disorder (BDD), a perceived de...
# 9999  Interventional                                                 NA
#
#                    interventions    purpose        intervention_type  \
# 0                   [Rocuronium]  Treatment      Parallel Assignment
# 1            [Mycophenolic Acid]  Treatment  Single Group Assignment
# 2     [Pembrolizumab, Sunitinib]  Treatment      Parallel Assignment
# 3                 [Atezolizumab]  Treatment    Sequential Assignment
# 4                     [Vaccines]  Treatment      Parallel Assignment
# ...                          ...        ...                      ...
# 9995                [Calcitriol]  Treatment      Parallel Assignment
# 9996                  [Olaparib]  Treatment      Parallel Assignment
# 9997                 [Acitretin]  Treatment      Parallel Assignment
# 9998             [Levetiracetam]  Treatment  Single Group Assignment
# 9999             [Rosiglitazone]  Treatment      Parallel Assignment
#
#                                              mesh_terms  \
# 0                                                    []
# 1     [Acquired Immunodeficiency Syndrome, HIV Infec...
# 2                    [Carcinoma, Carcinoma, Renal Cell]
# 3                  [Adenocarcinoma, Cholangiocarcinoma]
# 4                                              [Rabies]
# ...                                                 ...
# 9995                                        [Psoriasis]
# 9996             [Adenocarcinoma, Pancreatic Neoplasms]
# 9997                                        [Psoriasis]
# 9998               [Disease, Body Dysmorphic Disorders]
# 9999                                [Alzheimer Disease]
#
#                                                criteria   min_age    max_age  \
# 0     Inclusion Criteria:\n\nPatients 20 to 65 years...  20 Years   65 Years
# 1     Inclusion Criteria:\n\nConfirmed HIV infection...  18 Years   65 Years
# 2     Inclusion Criteria:\n\nHistologic confirmation...  18 Years         NA
# 3     Inclusion Criteria:\n\nFor both portions of th...  18 Years         NA
# 4     Inclusion Criteria:\n\nAble and willing to sig...  18 Years   75 Years
# ...                                                 ...       ...        ...
# 9995  Inclusion Criteria:\n\nMale or female 2 to 12 ...   2 Years   12 Years
# 9996  Key Inclusion Criteria\n\nHistologically or cy...  18 Years  130 Years
# 9997  Inclusion Criteria:\n\nMale or female subject ...  18 Years         NA
# 9998  Inclusion Criteria:\n\nMen and women age 18-65...  18 Years   65 Years
# 9999  Inclusion criteria:\n\nIs male, or if female m...  50 Years   85 Years
#
#      gender
# 0       All
# 1       All
# 2       All
# 3       All
# 4       All
# ...     ...
# 9995    All
# 9996    All
# 9997    All
# 9998    All
# 9999    All
#
# [10000 rows x 17 columns]

# %%
treatments = studies_table.explode('interventions')[['study_id', 'interventions']]
treatments = pd.DataFrame(treatments.groupby('interventions')['study_id'].apply(list).apply(len)).reset_index()

# %%
treatment_table = treatments.sort_values(by=['study_id'], ascending=False).rename(columns={
    'study_id': 'no_studies',
    'interventions':'name'
}).reset_index(drop=True)
treatment_table['from_study'] = True

# %%
treatment_table.to_csv('int_treatments_db.csv')

# %% [markdown]
# ## Groups Table

# %%
# We want to get the arm description and type, the baseline population numbers, and the
int_admins_sample = pd.read_pickle('int_admins_sample.pkl').reset_index(drop=True)

# %%
int_admins_sample['title_treats'] = [[z for z in y if z in x.lower()] for x,y in zip(int_admins_sample['title'], int_admins_sample['treatments'])]
title_treats_df = int_admins_sample.groupby('study_id')['title_treats'].apply(list).reset_index()
title_treats_df['title_treats_flat'] = [list(set([item for sublist in x for item in sublist])) for x in title_treats_df['title_treats']]
with_title_treats = int_admins_sample.merge(title_treats_df[['study_id', 'title_treats_flat']], 'inner', ['study_id'])
with_title_treats['subtracted'] = [[z for z in x if z not in y] for x,y in zip(with_title_treats['treatments'], with_title_treats['title_treats_flat'])]
with_title_treats['added'] = with_title_treats['subtracted'] + with_title_treats['title_treats']
adjusted_int_admins = with_title_treats.drop(columns=['title_treats', 'title_treats_flat', 'subtracted']).rename(columns={'added':'adjusted'})
adjusted_int_admins = adjusted_int_admins.drop_duplicates(['study_id', 'group_id', 'measure'])
adjusted_int_admins.head()
# Out:
#       study_id group_id                                            measure  \
# 0  NCT00262834    OG000         Number of Participants With Adverse Events
# 1  NCT00262834    OG000  Change in Tissue Proliferation After 3 Days of...
# 2  NCT00262834    OG001  Change in Tissue Proliferation After 3 Days of...
# 3  NCT00262834    OG000  Change in Tissue Apoptosis After 3 Days of Tre...
# 4  NCT00262834    OG001  Change in Tissue Apoptosis After 3 Days of Tre...
#
#          title                                        description  \
# 0   Vorinostat  Women in the vorinostat group were scheduled t...
# 1   Vorinostat  Women in the vorinostat group were scheduled t...
# 2  Tissue Only  Women who declined vorinostat but agreed to do...
# 3   Vorinostat  Women in the vorinostat group were scheduled t...
# 4  Tissue Only  Women who declined vorinostat but agreed to do...
#
#                                      desc_plus_title    treatments  \
# 0  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 1  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 2  Tissue Only Women who declined vorinostat but ...  [vorinostat]
# 3  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 4  Tissue Only Women who declined vorinostat but ...  [vorinostat]
#
#        adjusted
# 0  [vorinostat]
# 1  [vorinostat]
# 2            []
# 3  [vorinostat]
# 4            []

# %%
# Get the outcome groups
outcome_groups = adjusted_int_admins[['study_id', 'group_id', 'title', 'description']].drop_duplicates().reset_index(drop=True)

# %%
outcome_groups.to_csv('db_int_groups.csv') # There can be multiple titles for an id... wow

# %% [markdown]
# ## Administrations Table

# %%
admin_table = adjusted_int_admins[['group_id', 'adjusted', 'description']].rename(columns={
    'adjusted': 'treatments'}).drop_duplicates(['group_id', 'description']).reset_index(drop=True)

# %%
treats = treatment_table.rename(columns={'name': 'treatments'})
treats['treatments'] = treats['treatments'].str.lower()

# %%
# We need to get the new treatments migrated over to our table
admin_treats = admin_table.explode('treatments').merge(treats, 'left')

# %%
treats_to_add = admin_treats[~admin_treats['treatments'].isnull() & admin_treats['no_studies'].isnull()]['treatments'].unique()

# %%
len(treats_to_add)
# Out:
# 10897

# %%
no_studies_dummy = pd.Series(1, range(len(treats_to_add)))
from_study = pd.Series(False, range(len(treats_to_add)))
add_treats = pd.concat([pd.Series(treats_to_add), no_studies_dummy, from_study], axis=1).rename(columns={
    0: 'name',
    1: 'no_studies',
    2: 'from_study'
})

# %%
treatment_table = pd.concat([treatment_table, add_treats])

# %%
treatment_table.to_csv('int_treatments_db.csv')

# %%
# Now let's add on the

# %% [markdown]
# ## Effects Table

# %%
sample_int_studies(float('inf'), create_effects_table, 'new_effects')
# Out:
# writing study 0
# writing study 1

# %%
effects_table['no_effected'].apply(int)
# Out:
# 0         10
# 1         12
# 2          2
# 3          4
# 4          5
#           ..
# 909182     0
# 909183     2
# 909184     0
# 909185     2
# 909186     0
# Name: no_effected, Length: 909187, dtype: int64

# %%
effects_table['organ_system'].value_counts()
# Out:
# Gastrointestinal disorders                                             122097
# Infections and infestations                                            102008
# General disorders                                                       89102
# Skin and subcutaneous tissue disorders                                  69214
# Nervous system disorders                                                68276
# Investigations                                                          66467
# Respiratory, thoracic and mediastinal disorders                         64564
# Musculoskeletal and connective tissue disorders                         61054
# Metabolism and nutrition disorders                                      49236
# Psychiatric disorders                                                   29424
# Injury, poisoning and procedural complications                          28941
# Eye disorders                                                           28137
# Blood and lymphatic system disorders                                    25945
# Vascular disorders                                                      21942
# Renal and urinary disorders                                             21367
# Cardiac disorders                                                       17471
# Reproductive system and breast disorders                                11535
# Ear and labyrinth disorders                                              9007
# Hepatobiliary disorders                                                  5565
# Immune system disorders                                                  5148
# Neoplasms benign, malignant and unspecified (incl cysts and polyps)      4974
# Endocrine disorders                                                      3885
# Surgical and medical procedures                                          2014
# Congenital, familial and genetic disorders                                899
# Pregnancy, puerperium and perinatal conditions                            409
# Social circumstances                                                      279
# Product Issues                                                            227
# Name: organ_system, dtype: int64

# %% [markdown]
# ## Upload to Database

# %% [markdown]
# ### Studies

# %%
db_studies_table = studies_table[['study_id', 'verified_date', 'short_title', 'official_title', 'description', 'responsible_party', 'sponsor',
              'type', 'purpose', 'intervention_type', 'min_age', 'max_age', 'gender']].rename(columns={
    'study_id': 'id',
    'verified_date': 'upload_date',
})

# %%
db_studies_table['max_age_units'] = db_studies_table['max_age'].str.split(' ').apply(lambda x: x[1] if x != ['NA'] else 'NA')
db_studies_table['max_age_units'] = db_studies_table['max_age_units'].apply(lambda x: x + 's' if (x != 'NA' and x[-1] != 's') else x)
db_studies_table['max_age'] = db_studies_table['max_age'].str.split(' ').apply(lambda x: x[0] if x != ['NA'] else -1)

# %%
db_studies_table['min_age_units'] = db_studies_table['min_age'].str.split(' ').apply(lambda x: x[1] if x != ['NA'] else 'NA')
db_studies_table['min_age_units'] = db_studies_table['min_age_units'].apply(lambda x: x + 's' if (x != 'NA' and x[-1] != 's') else x)
db_studies_table['min_age'] = db_studies_table['min_age'].str.split(' ').apply(lambda x: x[0] if x != ['NA'] else -1)

# %%
db_studies_table['min_age'] = db_studies_table['min_age'].apply(int)
db_studies_table['max_age'] = db_studies_table['max_age'].apply(int)

# %%
db_studies_table = db_studies_table.set_index('id')

# %%
month_dict = {
    'January':1,
    'February':2,
    'March':3,
    'April':4,
    'May':5,
    'June':6,
    'July':7,
    'August':8,
    'September':9,
    'October':10,
    'November':11,
    'December':12,
}

db_studies_table['upload_date'] = db_studies_table['upload_date'].str.split(' ').apply(lambda x: x[-1]) + '-' + db_studies_table['upload_date'].str.split(' ').apply(lambda x: str(month_dict[x[0]])) + "-01"

# %%
db_studies_table = db_studies_table[['upload_date', 'short_title', 'official_title', 'description', 'responsible_party', 'sponsor',
              'type', 'purpose', 'intervention_type', 'min_age', 'min_age_units', 'max_age', 'max_age_units', 'gender']]
db_studies_table['intervention_type'] = db_studies_table['intervention_type'].str.upper()
db_studies_table['intervention_type'] = db_studies_table['intervention_type'].str.replace(' ', '_')
db_studies_table['type'] = db_studies_table['type'].str.upper()
db_studies_table['type'] = db_studies_table['type'].str.replace(' ', '_')
db_studies_table['purpose'] = db_studies_table['purpose'].str.upper()
db_studies_table['purpose'] = db_studies_table['purpose'].str.replace(' ', '_')
db_studies_table['min_age_units'] = db_studies_table['min_age_units'].str.upper()
db_studies_table['max_age_units'] = db_studies_table['max_age_units'].str.upper()
db_studies_table['gender'] = db_studies_table['gender'].str.upper()

# %%
db_studies_table.head()
# Out:
#             upload_date                                        short_title  \
# id
# NCT03266419  2019-10-01  Effectiveness of Deep Versus Moderate Neuromus...
# NCT03262441  2020-11-01                    MMF for HIV Reservoir Reduction
# NCT03260894   2020-8-01  Pembrolizumab (MK-3475) Plus Epacadostat vs St...
# NCT03267940   2020-1-01  Study of PEGPH20 With Cisplatin (CIS) and Gemc...
# NCT03264157   2020-1-01  Safety and Effectiveness of BPL HRIG With Acti...
#
#                                                 official_title  \
# id
# NCT03266419  A Double-blind, Randomized, Parallel Design to...
# NCT03262441  Mycophenolate Mofetil Therapy for Reduction of...
# NCT03260894  A Randomized, Open-Label, Phase 3 Study to Eva...
# NCT03267940  A Phase 1B, Randomized, Open-Label Study of PE...
# NCT03264157  A Prospective, Randomized, Double-Blind Parall...
#
#                                                    description  \
# id
# NCT03266419  The aim of this study is to evaluate the influ...
# NCT03262441  This is an open label, randomized Phase II stu...
# NCT03260894  The purpose of this study was to evaluate the ...
# NCT03267940  The study is being conducted to assess the saf...
# NCT03264157  A prospective, randomized, blinded, parallel-g...
#
#             responsible_party                                 sponsor  \
# id
# NCT03266419   Byung-Moon Choi                     Asan Medical Center
# NCT03262441   Joshua Schiffer  Fred Hutchinson Cancer Research Center
# NCT03260894                NA                      Incyte Corporation
# NCT03267940                NA                   Halozyme Therapeutics
# NCT03264157                NA                 Bio Products Laboratory
#
#                        type    purpose        intervention_type  min_age  \
# id
# NCT03266419  INTERVENTIONAL  TREATMENT      PARALLEL_ASSIGNMENT       20
# NCT03262441  INTERVENTIONAL  TREATMENT  SINGLE_GROUP_ASSIGNMENT       18
# NCT03260894  INTERVENTIONAL  TREATMENT      PARALLEL_ASSIGNMENT       18
# NCT03267940  INTERVENTIONAL  TREATMENT    SEQUENTIAL_ASSIGNMENT       18
# NCT03264157  INTERVENTIONAL  TREATMENT      PARALLEL_ASSIGNMENT       18
#
#             min_age_units  max_age max_age_units gender
# id
# NCT03266419         YEARS       65         YEARS    ALL
# NCT03262441         YEARS       65         YEARS    ALL
# NCT03260894         YEARS       -1            NA    ALL
# NCT03267940         YEARS       -1            NA    ALL
# NCT03264157         YEARS       75         YEARS    ALL

# %%
db_studies_table.to_csv('db_int_studies.csv', header=False)

# %% [markdown]
# ### Conditions

# %% [markdown]
# ### Measures

# %%
measures_table_0 = pd.read_pickle('int_measures_0.pkl')
measures_table_1 = pd.read_pickle('int_measures_1.pkl')
measures_table_2 = pd.read_pickle('int_measures_2.pkl')

measures_table = pd.concat([measures_table_0, measures_table_1, measures_table_2]).reset_index(drop=True)

# %%
db_measures_table = measures_table.rename(columns={
    'study_id': 'study',
    'measure': 'title',
    'dispersion_param': 'dispersion',
    'measure_param': 'param'
}).rename_axis(['id'], axis=0)

# %%
dispersion_map = {
    'Standard Deviation': 'STANDARD_DEVIATION',
    '95% Confidence Interval': 'CONFIDENCE_INTERVAL_95',
    'Standard Error': 'STANDARD_ERROR',
    'Full Range': 'FULL_RANGE',
    'Geometric Coefficient of Variation': 'GEOMETRIC_COEFFICIENT_OF_VARIATION',
    'Inter-Quartile Range': 'INTER_QUARTILE_RANGE',
    '90% Confidence Interval': 'CONFIDENCE_INTERVAL_90',
    '80% Confidence Interval': 'CONFIDENCE_INTERVAL_80',
    '97% Confidence Interval': 'CONFIDENCE_INTERVAL_97',
    '99% Confidence Interval': 'CONFIDENCE_INTERVAL_99',
    '60% Confidence Interval': 'CONFIDENCE_INTERVAL_60',
    '96% Confidence Interval': 'CONFIDENCE_INTERVAL_96',
    '98% Confidence Interval': 'CONFIDENCE_INTERVAL_98',
    '70% Confidence Interval': 'CONFIDENCE_INTERVAL_70',
    '85% Confidence Interval': 'CONFIDENCE_INTERVAL_85',
    '75% Confidence Interval': 'CONFIDENCE_INTERVAL_75',
    '94% Confidence Interval': 'CONFIDENCE_INTERVAL_94',
    '100% Confidence Interval': 'CONFIDENCE_INTERVAL_100',
    'NA': 'NA'
}

db_measures_table['dispersion'] = db_measures_table['dispersion'].apply(lambda x: x if '.' not in x else x[:x.index('.')] + x[x.index('%'):]).apply(lambda x: dispersion_map[x])

# %%
db_measures_table['param'] = db_measures_table['param'].str.upper().str.replace(' ', '_')

# %%
measure_type_map = {
    'Primary': 'PRIMARY',
    'Secondary': 'SECONDARY',
    'Other Pre-specified': 'OTHER',
    'Post-Hoc': 'OTHER'
}


db_measures_table['type'] = db_measures_table['type'].apply(lambda x: measure_type_map[x])

# %%
db_measures_table = db_measures_table[['study', 'title', 'description', 'dispersion',  'type', 'param', 'units']]

# %%
db_measures_table['description'].str.len().max()
# Out:
# 1004

# %%
db_measures_table.head()
# Out:
#           study                                              title  \
# id
# 0   NCT03266419  Minimum Effective Analgesic Dose (MEAD) of Oxy...
# 1   NCT03266419  Mean Visual Analogue Scale (VAS) Score for Wou...
# 2   NCT03262441  Change in Cell-associated HIV DNA (Ca-DNA) Lev...
# 3   NCT03262441  Change in Cell-associated HIV DNA (Ca-DNA) Lev...
# 4   NCT03262441  Change in Cell-associated Intact HIV DNA (Ca-i...
#
#                                           description              dispersion  \
# id
# 0   The patient was administered intravenous oxyco...              FULL_RANGE
# 1   The patient was administered intravenous oxyco...              FULL_RANGE
# 2   Regression slope of change in cell-associated ...  CONFIDENCE_INTERVAL_95
# 3   Regression slope of change in cell-associated ...  CONFIDENCE_INTERVAL_95
# 4   Regression slope of change in cell-associated ...  CONFIDENCE_INTERVAL_95
#
#          type   param                                     units
# id
# 0     PRIMARY  MEDIAN                                        mg
# 1   SECONDARY    MEAN                                        mm
# 2     PRIMARY    MEAN  log10 caDNA copies per 10^6 T-cells/week
# 3     PRIMARY    MEAN  log10 caDNA copies per 10^6 T-cells/week
# 4     PRIMARY    MEAN  log10 caDNA copies per 10^6 T-cells/week

# %%
db_measures_table.to_csv('db_int_measures.csv', header=False)

# %% [markdown]
# ### Treatments

# %%
treatments = studies_table.explode('interventions')[['study_id', 'interventions']]
treatments = pd.DataFrame(treatments.groupby('interventions')['study_id'].apply(list).apply(len)).reset_index()
treatment_table = treatments.sort_values(by=['study_id'], ascending=False).rename(columns={
    'study_id': 'no_studies',
    'interventions':'name'
}).reset_index(drop=True)
treatment_table['from_study'] = True

# %%
analytics_table = pd.read_pickle('intervention_analytics.pkl')

# %%
treats_a = analytics_table.explode('treatments_a')['treatments_a']
treats_b = analytics_table.explode('treatments_b')['treatments_b']
treats = pd.Series(pd.concat([treats_a, treats_b]).unique())

# %%
treats = treats.str.capitalize()

# %%
treats = pd.Series([x for x in treats if x not in set(treatment_table['name'])])

# %%
treats_df = pd.DataFrame(treats)

# %%
treats_df['from_study'] = False

# %%
treats_df['no_studies'] = -1

# %%
treats_df = treats_df.rename(columns={0: 'name'})

# %%
treatment_table = pd.concat([treatment_table, treats_df])

# %%
treatment_table = treatment_table.rename(columns = {
    'name': 'title'
})[['title', 'from_study', 'no_studies']]

# %%
treatment_table = treatment_table.reset_index(drop=True)

# %%
treatment_table.to_csv('db_int_treatments.csv', header=False)

# %% [markdown]
# ### Groups

# %%
groups_table = pd.read_csv('db_int_groups.csv')

# %%
groups_table = groups_table.rename_axis(['id'], axis=0).drop(columns=['Unnamed: 0'])

# %%
groups_table = groups_table.rename(columns={
    'study_id': 'study',
    'group_id': 'study_id',
})[['title', 'study_id', 'description', 'study']]

# %%
groups_table.to_csv('db_int_groups.csv', header=False)

# %% [markdown]
# ### Administration

# %%
adjusted_int_admins.head()
# Out:
#       study_id group_id                                            measure  \
# 0  NCT00262834    OG000         Number of Participants With Adverse Events
# 1  NCT00262834    OG000  Change in Tissue Proliferation After 3 Days of...
# 2  NCT00262834    OG001  Change in Tissue Proliferation After 3 Days of...
# 3  NCT00262834    OG000  Change in Tissue Apoptosis After 3 Days of Tre...
# 4  NCT00262834    OG001  Change in Tissue Apoptosis After 3 Days of Tre...
#
#          title                                        description  \
# 0   Vorinostat  Women in the vorinostat group were scheduled t...
# 1   Vorinostat  Women in the vorinostat group were scheduled t...
# 2  Tissue Only  Women who declined vorinostat but agreed to do...
# 3   Vorinostat  Women in the vorinostat group were scheduled t...
# 4  Tissue Only  Women who declined vorinostat but agreed to do...
#
#                                      desc_plus_title    treatments  \
# 0  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 1  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 2  Tissue Only Women who declined vorinostat but ...  [vorinostat]
# 3  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 4  Tissue Only Women who declined vorinostat but ...  [vorinostat]
#
#        adjusted
# 0  [vorinostat]
# 1  [vorinostat]
# 2            []
# 3  [vorinostat]
# 4            []

# %%
# Merge with treatments to get the id
expl_admins = adjusted_int_admins.explode('adjusted')

# %%
expl_admins['adjusted'] = expl_admins['adjusted'].str.capitalize()
expl_admins.head()
# Out:
#       study_id group_id                                            measure  \
# 0  NCT00262834    OG000         Number of Participants With Adverse Events
# 1  NCT00262834    OG000  Change in Tissue Proliferation After 3 Days of...
# 2  NCT00262834    OG001  Change in Tissue Proliferation After 3 Days of...
# 3  NCT00262834    OG000  Change in Tissue Apoptosis After 3 Days of Tre...
# 4  NCT00262834    OG001  Change in Tissue Apoptosis After 3 Days of Tre...
#
#          title                                        description  \
# 0   Vorinostat  Women in the vorinostat group were scheduled t...
# 1   Vorinostat  Women in the vorinostat group were scheduled t...
# 2  Tissue Only  Women who declined vorinostat but agreed to do...
# 3   Vorinostat  Women in the vorinostat group were scheduled t...
# 4  Tissue Only  Women who declined vorinostat but agreed to do...
#
#                                      desc_plus_title    treatments    adjusted
# 0  Vorinostat Women in the vorinostat group were ...  [vorinostat]  Vorinostat
# 1  Vorinostat Women in the vorinostat group were ...  [vorinostat]  Vorinostat
# 2  Tissue Only Women who declined vorinostat but ...  [vorinostat]         NaN
# 3  Vorinostat Women in the vorinostat group were ...  [vorinostat]  Vorinostat
# 4  Tissue Only Women who declined vorinostat but ...  [vorinostat]         NaN

# %%
treatment_table.head()
# Out:
#               title  from_study  no_studies
# 0  Cyclophosphamide        True         678
# 1          Vaccines        True         644
# 2        Paclitaxel        True         621
# 3       Bevacizumab        True         607
# 4     Dexamethasone        True         542

# %%
treatment_merge = treatment_table.rename_axis(['id'], axis=0).rename(columns={
    'title': 'adjusted'
})

# %%
treatment_merge['treatment'] = treatment_merge.index

# %%
admins_treats = expl_admins.merge(treatment_merge[['adjusted', 'treatment']], 'left', ['adjusted'])

# %%
# losing a little less than 1% but still not good practice
admins_treats = admins_treats[~admins_treats['treatment'].isna()]

# %%
admins_treats.head()
# Out:
#       study_id group_id                                            measure  \
# 0  NCT00262834    OG000         Number of Participants With Adverse Events
# 1  NCT00262834    OG000  Change in Tissue Proliferation After 3 Days of...
# 2  NCT00262834    OG001  Change in Tissue Proliferation After 3 Days of...
# 3  NCT00262834    OG000  Change in Tissue Apoptosis After 3 Days of Tre...
# 4  NCT00262834    OG001  Change in Tissue Apoptosis After 3 Days of Tre...
#
#          title                                        description  \
# 0   Vorinostat  Women in the vorinostat group were scheduled t...
# 1   Vorinostat  Women in the vorinostat group were scheduled t...
# 2  Tissue Only  Women who declined vorinostat but agreed to do...
# 3   Vorinostat  Women in the vorinostat group were scheduled t...
# 4  Tissue Only  Women who declined vorinostat but agreed to do...
#
#                                      desc_plus_title    treatments  \
# 0  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 1  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 2  Tissue Only Women who declined vorinostat but ...  [vorinostat]
# 3  Vorinostat Women in the vorinostat group were ...  [vorinostat]
# 4  Tissue Only Women who declined vorinostat but ...  [vorinostat]
#
#      adjusted  treatment
# 0  Vorinostat      111.0
# 1  Vorinostat      111.0
# 2         NaN     2182.0
# 3  Vorinostat      111.0
# 4         NaN     2182.0

# %%
groups_table['group'] = groups_table.index

# %%
groups_merge = groups_table.rename(columns = {
    'study_id': 'group_id',
    'study': 'study_id'
})[['title', 'group_id', 'study_id', 'group']]

# %%
admin_db = admins_treats.merge(groups_merge, 'left', ['study_id', 'group_id', 'title'])[['group', 'treatment', 'description']].reset_index(drop=True).drop_duplicates()

# %%
admin_db['treatment'] = admin_db['treatment'].apply(int)

# %%
admin_db['description'].str.len().max()
# Out:
# 1490

# %%
admin_db.to_csv('db_int_admin.csv', header=False)

# %% [markdown]
# ### Outcomes

# %%
outcomes_0 = pd.read_pickle('int_new_outcomes_0.pkl')
outcomes_1 = pd.read_pickle('int_new_outcomes_1.pkl')
outcomes_2 = pd.read_pickle('int_new_outcomes_2.pkl')

outcomes = pd.concat([outcomes_0, outcomes_1, outcomes_2]).reset_index(drop=True)

# %%
outcomes
# Out:
#             study_id                    group_title group_no  \
# 0        NCT03266419      Deep NMB Using Rocuronium    OG000
# 1        NCT03266419  Moderate NMB Using Rocuronium    OG001
# 2        NCT03266419      Deep NMB Using Rocuronium    OG000
# 3        NCT03266419  Moderate NMB Using Rocuronium    OG001
# 4        NCT03262441          Mycophenolate Mofetil    OG000
# ...              ...                            ...      ...
# 1707752  NCT03031496                    Treatment B    OG001
# 1707753  NCT03031496                    Treatment A    OG000
# 1707754  NCT03031496                    Treatment B    OG001
# 1707755  NCT03031496                    Treatment A    OG000
# 1707756  NCT03031496                    Treatment B    OG001
#
#                                                    measure  \
# 0        Minimum Effective Analgesic Dose (MEAD) of Oxy...
# 1        Minimum Effective Analgesic Dose (MEAD) of Oxy...
# 2        Mean Visual Analogue Scale (VAS) Score for Wou...
# 3        Mean Visual Analogue Scale (VAS) Score for Wou...
# 4        Change in Cell-associated HIV DNA (Ca-DNA) Lev...
# ...                                                    ...
# 1707752   Body Temperature Values at Indicated Time Points
# 1707753   Body Temperature Values at Indicated Time Points
# 1707754   Body Temperature Values at Indicated Time Points
# 1707755   Body Temperature Values at Indicated Time Points
# 1707756   Body Temperature Values at Indicated Time Points
#
#                                           title     value dispersion   upper  \
# 0                                            NA       8.0         NA      26
# 1                                            NA       8.0         NA      27
# 2                                            NA       6.1         NA     8.4
# 3                                            NA       6.1         NA     7.3
# 4                                            NA  -0.00033         NA  0.0014
# ...                                         ...       ...        ...     ...
# 1707752   P2; Day1; 8 hour post-dose; n= 19, 19     36.65      0.399      NA
# 1707753  P2; Day2; 24 hour post-dose; n= 19, 19     36.15      0.301      NA
# 1707754  P2; Day2; 24 hour post-dose; n= 19, 19     36.17      0.437      NA
# 1707755  P2; Day3; 48 hour post-dose; n= 18, 19     36.08      0.323      NA
# 1707756  P2; Day3; 48 hour post-dose; n= 18, 19     36.28      0.486      NA
#
#            lower participants
# 0              2           51
# 1              2           49
# 2            2.8           51
# 3            2.7           49
# 4        -0.0020            4
# ...          ...          ...
# 1707752       NA           19
# 1707753       NA           19
# 1707754       NA           19
# 1707755       NA           18
# 1707756       NA           19
#
# [1707757 rows x 10 columns]

# %%
groups = pd.read_csv('meditreats_public_groups.csv')

# %%
groups.head()
# Out:
#    id                           title study_id  \
# 0   0                      Vorinostat    OG000
# 1   1                     Tissue Only    OG001
# 2   2                           Arm I    OG000
# 3   3  Low CIWA Flumazenil/Gabapentin    OG000
# 4   4              Low CIWAar Placebo    OG001
#
#                                          description        study
# 0  Women in the vorinostat group were scheduled t...  NCT00262834
# 1  Women who declined vorinostat but agreed to do...  NCT00262834
# 2  Patients receive oral vorinostat twice daily o...  NCT00262834
# 3  2 mg flumazenil given over 20 minutes on Day 1...  NCT00262639
# 4  20 mg Saline infused slowly over 20 minutes. P...  NCT00262639

# %%
groups[groups['study'] == 'NCT02460380']
# Out:
#           id       title study_id  \
# 39489  39360  Vitamin D3    OG000
# 39490  39361     Placebo    OG001
#
#                                              description        study
# 39489  Women allocated to vitamin D3 group received o...  NCT02460380
# 39490  Women in the placebo group received once capsu...  NCT02460380

# %%
groups_merge = groups.rename(columns={
    'title': 'group_title',
    'study': 'study_id',
    'study_id': 'group_no'
})

# %%
groups_merge.head()
# Out:
#    id                     group_title group_no  \
# 0   0                      Vorinostat    OG000
# 1   1                     Tissue Only    OG001
# 2   2                           Arm I    OG000
# 3   3  Low CIWA Flumazenil/Gabapentin    OG000
# 4   4              Low CIWAar Placebo    OG001
#
#                                          description     study_id
# 0  Women in the vorinostat group were scheduled t...  NCT00262834
# 1  Women who declined vorinostat but agreed to do...  NCT00262834
# 2  Patients receive oral vorinostat twice daily o...  NCT00262834
# 3  2 mg flumazenil given over 20 minutes on Day 1...  NCT00262639
# 4  20 mg Saline infused slowly over 20 minutes. P...  NCT00262639

# %%
merged = outcomes.merge(groups_merge[['group_title', 'study_id', 'id', 'group_no']], 'left', ['study_id', 'group_title', 'group_no']).drop_duplicates()

# %%
outcome_table = merged[~merged['id'].isna()]

# %%
# Now let's merge in the meeasures 
measures = pd.read_csv('meditreats_public_measures.csv')

# %%
measures.head()
# Out:
#     id        study                                              title  \
# 0  278  NCT03322566  Duration of Response of Pembrolizumab + Chemot...
# 1  279  NCT03322566  Safety and Tolerability of Pembrolizumab + Che...
# 2  280  NCT03322566  Safety and Tolerability of Pembrolizumab + Che...
# 3  281  NCT03324451   Change in Glycosylated Hemoglobin (HbA1c) Levels
# 4  282  NCT03324451             Change in Diabetes Empowerment Process
#
#                                          description              dispersion  \
# 0  Defined as the time from the earliest date of ...  CONFIDENCE_INTERVAL_95
# 1  An AE is defined as any untoward medical occur...                     NaN
# 2  An AE is defined as any untoward medical occur...                     NaN
# 3  Collected from blood test to assess the Glycos...      STANDARD_DEVIATION
# 4  A 13-item Chinese version of the Diabetes Empo...      STANDARD_DEVIATION
#
#         type                  param                       units
# 0  SECONDARY                 MEDIAN                      months
# 1  SECONDARY  COUNT_OF_PARTICIPANTS                Participants
# 2  SECONDARY  COUNT_OF_PARTICIPANTS                Participants
# 3    PRIMARY                   MEAN  percent of glycosylated Hb
# 4  SECONDARY                   MEAN            score on a scale

# %%
measures_merge = measures.rename(columns = {
    'study': 'study_id',
    'title': 'measure'
})[['id', 'study_id', 'measure']].drop_duplicates(['study_id', 'measure'])

# %%
outcome_table = outcome_table.merge(measures_merge, 'left', ['study_id', 'measure'])

# %%
outcome_table.head()
# Out:
#       study_id                    group_title group_no  \
# 0  NCT03266419      Deep NMB Using Rocuronium    OG000
# 1  NCT03266419  Moderate NMB Using Rocuronium    OG001
# 2  NCT03266419      Deep NMB Using Rocuronium    OG000
# 3  NCT03266419  Moderate NMB Using Rocuronium    OG001
# 4  NCT03262441          Mycophenolate Mofetil    OG000
#
#                                              measure title     value  \
# 0  Minimum Effective Analgesic Dose (MEAD) of Oxy...    NA       8.0
# 1  Minimum Effective Analgesic Dose (MEAD) of Oxy...    NA       8.0
# 2  Mean Visual Analogue Scale (VAS) Score for Wou...    NA       6.1
# 3  Mean Visual Analogue Scale (VAS) Score for Wou...    NA       6.1
# 4  Change in Cell-associated HIV DNA (Ca-DNA) Lev...    NA  -0.00033
#
#   dispersion   upper    lower participants     id_x  id_y
# 0         NA      26        2           51  35418.0     0
# 1         NA      27        2           49  35419.0     0
# 2         NA     8.4      2.8           51  35418.0     1
# 3         NA     7.3      2.7           49  35419.0     1
# 4         NA  0.0014  -0.0020            4  35420.0     2

# %%
outcome_db = outcome_table.rename(columns={
    'study_id': 'study',
    'id_x': 'group',
    'id_y': 'measure',
    'measure': 'measure_title',
    'participants': 'no_participants'
})[['study', 'group', 'measure', 'title', 'value', 'dispersion', 'upper', 'lower', 'no_participants']]

# %%
outcome_db['group'] = outcome_db['group'].apply(int)

# %%
def string2float(string):
    try:
        return float(string.replace(',', ''))
    except Exception as e:
        return float('nan')
    
    
def string2int(string):
    try:
        return int(string.replace(',',''))
    except Exception as e:
        return -1

# %%
outcome_db.head()
# Out:
#          study  group  measure title    value  dispersion    upper  lower  \
# 0  NCT03266419  35418        0    NA  8.00000         NaN  26.0000  2.000
# 1  NCT03266419  35419        0    NA  8.00000         NaN  27.0000  2.000
# 2  NCT03266419  35418        1    NA  6.10000         NaN   8.4000  2.800
# 3  NCT03266419  35419        1    NA  6.10000         NaN   7.3000  2.700
# 4  NCT03262441  35420        2    NA -0.00033         NaN   0.0014 -0.002
#
#    no_participants
# 0               51
# 1               49
# 2               51
# 3               49
# 4                4

# %%
outcome_db['value'] = outcome_db['value'].apply(string2float)

# %%
outcome_db['dispersion'] = outcome_db['dispersion'].apply(string2float)

# %%
outcome_db['upper'] = outcome_db['upper'].apply(string2float)

# %%
outcome_db['lower'] = outcome_db['lower'].apply(string2float)

# %%
outcome_db['no_participants'] = outcome_db['no_participants'].apply(string2int)

# %%
outcome_db.to_csv('int_db_outcome.csv', header=False)

# %%
outcome_db['no_participants']
# Out:
# 0          51
# 1          49
# 2          51
# 3          49
# 4           4
#            ..
# 2023779    19
# 2023780    19
# 2023781    19
# 2023782    18
# 2023783    19
# Name: no_participants, Length: 2023784, dtype: int64

# %%
# We're going to have to do a direct connection due to the nans in the float column
from sqlalchemy import create_engine

db = create_engine("postgresql://meditreats:meditreats@localhost:5432/meditreats")

# %%
outcome_db.to_sql('outcomes', db, index=False, if_exists='append')

# %% [markdown]
# ### Analytics Table

# %%
# This is going to be a pain
# There aare so little studies that can actually be analyzed with this current method...

non_study_analytics = pd.read_pickle('int_analytics.pkl')
non_study_analytics = non_study_analytics[non_study_analytics['pval'] > 0].reset_index(drop=True)

# %%
non_study_analytics.head()
# Out:
#       study_id                 measure          groups description  method  \
# 0  NCT00262639  Percent Days Abstinent  [OG001, OG003]          NA  t-test
# 1  NCT00262639  Percent Days Abstinent  [OG000, OG003]          NA  t-test
# 2  NCT00262639  Percent Days Abstinent  [OG000, OG001]          NA  t-test
# 3  NCT00262639  Percent Days Abstinent  [OG002, OG003]          NA  t-test
# 4  NCT00262639  Percent Days Abstinent  [OG002, OG001]          NA  t-test
#
#   param_type  fromStudy      pval  \
# 0          ?      False  0.236682
# 1          ?      False  0.014809
# 2          ?      False  0.029790
# 3          ?      False  0.084525
# 4          ?      False  0.247262
#
#                                         group_titles
# 0  {'OG001': 'Low CIWAar Placebo', 'OG003': 'High...
# 1  {'OG000': 'Low CIWA Flumazenil/Gabapentin', 'O...
# 2  {'OG000': 'Low CIWA Flumazenil/Gabapentin', 'O...
# 3  {'OG002': 'High CIWAar Placebo', 'OG003': 'Hig...
# 4  {'OG002': 'High CIWAar Placebo', 'OG001': 'Low...

# %%
analytics_0 = pd.read_pickle('int_new_analytics_0.pkl')
analytics_1 = pd.read_pickle('int_new_analytics_1.pkl')
analytics_2 = pd.read_pickle('int_new_analytics_2.pkl')

study_analytics = pd.concat([analytics_0, analytics_1, analytics_2]).reset_index(drop=True)

# %%
study_analytics.head()
# Out:
#       study_id                                            measure  \
# 0  NCT03262441  Change in Cell-associated HIV DNA (Ca-DNA) Lev...
# 1  NCT03262441  Change in Cell-associated HIV DNA (Ca-DNA) Lev...
# 2  NCT03262441  Change in Cell-associated Intact HIV DNA (Ca-i...
# 3  NCT03264157  Proportion of Subjects With Anti-rabies Antibo...
# 4  NCT03264157                                Analysis of AUC0-7d
#
#            groups description                       method    param_type  \
# 0         [OG000]          NA                           NA         Slope
# 1         [OG000]          NA                           NA         Slope
# 2         [OG000]          NA                           NA         Slope
# 3  [OG000, OG001]          NA  Farrington and Manning test  lower 95% CI
# 4  [OG000, OG001]          NA                           NA  lower 95% CI
#
#    fromStudy    pval                                       group_titles  \
# 0       True      NA                 {'OG000': 'Mycophenolate Mofetil'}
# 1       True      NA                 {'OG000': 'Mycophenolate Mofetil'}
# 2       True      NA                 {'OG000': 'Mycophenolate Mofetil'}
# 3       True  0.0006  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...
# 4       True      NA  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...
#
#   is_non_inferiority non_inferiority_type  \
# 0                 NA                Other
# 1                 NA                Other
# 2                 NA                Other
# 3                 NA      Non-Inferiority
# 4                 NA      Non-Inferiority
#
#                              non_inferiority_comment param_value ci_pct  \
# 0                                                 NA    -0.00033     95
# 1                                                 NA       0.001     95
# 2                                                 NA      0.0024     95
# 3  The null hypothesis is p-p0 ≤ -0.1. The altern...       -0.05     95
# 4  The prespecified non inferiority margin was 20...        0.74     95
#
#   ci_lower ci_upper
# 0  -0.0020   0.0014
# 1  -0.0036   0.0056
# 2   -0.003   0.0078
# 3    -0.05       NA
# 4     0.74     0.94

# %%
# 1. Get both in the same table
# 2. Merge in the measures 
non_study_analytics['is_non_inferiority'] = False
non_study_analytics['non_inferiority_type'] = 'NA'
non_study_analytics['non_inferiority_comment'] = 'NA'
non_study_analytics['param_value'] = float('nan')
non_study_analytics['ci_pct'] = -1
non_study_analytics['ci_lower'] = -1
non_study_analytics['ci_upper'] = -1

non_study_analytics.head()
# Out:
#       study_id                 measure          groups description  method  \
# 0  NCT00262639  Percent Days Abstinent  [OG001, OG003]          NA  t-test
# 1  NCT00262639  Percent Days Abstinent  [OG000, OG003]          NA  t-test
# 2  NCT00262639  Percent Days Abstinent  [OG000, OG001]          NA  t-test
# 3  NCT00262639  Percent Days Abstinent  [OG002, OG003]          NA  t-test
# 4  NCT00262639  Percent Days Abstinent  [OG002, OG001]          NA  t-test
#
#   param_type  fromStudy      pval  \
# 0          ?      False  0.236682
# 1          ?      False  0.014809
# 2          ?      False  0.029790
# 3          ?      False  0.084525
# 4          ?      False  0.247262
#
#                                         group_titles  is_non_inferiority  \
# 0  {'OG001': 'Low CIWAar Placebo', 'OG003': 'High...               False
# 1  {'OG000': 'Low CIWA Flumazenil/Gabapentin', 'O...               False
# 2  {'OG000': 'Low CIWA Flumazenil/Gabapentin', 'O...               False
# 3  {'OG002': 'High CIWAar Placebo', 'OG003': 'Hig...               False
# 4  {'OG002': 'High CIWAar Placebo', 'OG001': 'Low...               False
#
#   non_inferiority_type non_inferiority_comment  param_value  ci_pct  ci_lower  \
# 0                   NA                      NA          NaN      -1        -1
# 1                   NA                      NA          NaN      -1        -1
# 2                   NA                      NA          NaN      -1        -1
# 3                   NA                      NA          NaN      -1        -1
# 4                   NA                      NA          NaN      -1        -1
#
#    ci_upper
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1

# %%
total_analytics = pd.concat([study_analytics, non_study_analytics]).reset_index(drop=True)

# %%
measures = pd.read_csv('meditreats_public_measures.csv')

# %%
measures.head()
# Out:
#     id        study                                              title  \
# 0  278  NCT03322566  Duration of Response of Pembrolizumab + Chemot...
# 1  279  NCT03322566  Safety and Tolerability of Pembrolizumab + Che...
# 2  280  NCT03322566  Safety and Tolerability of Pembrolizumab + Che...
# 3  281  NCT03324451   Change in Glycosylated Hemoglobin (HbA1c) Levels
# 4  282  NCT03324451             Change in Diabetes Empowerment Process
#
#                                          description              dispersion  \
# 0  Defined as the time from the earliest date of ...  CONFIDENCE_INTERVAL_95
# 1  An AE is defined as any untoward medical occur...                     NaN
# 2  An AE is defined as any untoward medical occur...                     NaN
# 3  Collected from blood test to assess the Glycos...      STANDARD_DEVIATION
# 4  A 13-item Chinese version of the Diabetes Empo...      STANDARD_DEVIATION
#
#         type                  param                       units
# 0  SECONDARY                 MEDIAN                      months
# 1  SECONDARY  COUNT_OF_PARTICIPANTS                Participants
# 2  SECONDARY  COUNT_OF_PARTICIPANTS                Participants
# 3    PRIMARY                   MEAN  percent of glycosylated Hb
# 4  SECONDARY                   MEAN            score on a scale

# %%
measures_merge = measures[['id', 'study', 'title']].rename(columns={
    'study': 'study_id',
    'title': 'measure'
})

# %%
len(total_analytics)
# Out:
# 1003970

# %%
total_analytics = total_analytics.merge(measures_merge, 'left', ['study_id', 'measure']).drop(columns=['measure']).rename(columns={
    'id': 'measure'
})

# %%
db_analytics = total_analytics.rename(columns={
    'study_id': 'study',
    'id': 'measure',
    'fromStudy': 'from_study',
    'pval': 'p_value',
})[['study', 'measure', 'from_study', 'method', 'p_value', 'param_type', 'is_non_inferiority', 'non_inferiority_type', 
    'non_inferiority_comment', 'param_value', 'ci_pct', 'ci_lower', 'ci_upper', 'groups', 'group_titles']]

# %%
db_analytics['param_value'] = db_analytics['param_value'].apply(str)
db_analytics['param_value'] = db_analytics['param_value'].apply(string2float)

# %%
db_analytics['ci_pct'] = db_analytics['ci_pct'].apply(str)
db_analytics['ci_pct'] = db_analytics['ci_pct'].apply(string2int)

# %%
db_analytics['ci_lower'] = db_analytics['ci_lower'].apply(str)
db_analytics['ci_lower'] = db_analytics['ci_lower'].apply(string2float)

# %%
db_analytics['ci_upper'] = db_analytics['ci_upper'].apply(str)
db_analytics['ci_upper'] = db_analytics['ci_upper'].apply(string2float)

# %%
db_analytics['p_value'] = db_analytics['p_value'].apply(str)
db_analytics['p_value'] = db_analytics['p_value'].apply(string2float)

# %%
db_analytics['is_non_inferiority'] = db_analytics['is_non_inferiority'].apply(lambda x: False if (x=='NA') or (not x) else True)

# %%
db_analytics['non_inferiority_type'] = db_analytics['non_inferiority_type'].str.upper().str.replace('-','_',regex=False).str.replace(' ','_', regex=False).str.replace('(','', regex=False).str.replace(')', '', regex=False)

# %%
db_analytics['id'] = db_analytics.index.to_series()

# %%
db_analytics
# Out:
#                study  measure  from_study                       method  \
# 0        NCT03262441        2        True                           NA
# 1        NCT03262441        3        True                           NA
# 2        NCT03262441        4        True                           NA
# 3        NCT03264157       32        True  Farrington and Manning test
# 4        NCT03264157       33        True                           NA
# ...              ...      ...         ...                          ...
# 1037249  NCT03031496   226580       False                       t-test
# 1037250  NCT03031496   226583       False                       t-test
# 1037251  NCT03031496   226583       False                       t-test
# 1037252  NCT03031496   226583       False                       t-test
# 1037253  NCT03031496   226583       False                       t-test
#
#           p_value    param_type  is_non_inferiority non_inferiority_type  \
# 0             NaN         Slope               False                OTHER
# 1             NaN         Slope               False                OTHER
# 2             NaN         Slope               False                OTHER
# 3        0.000600  lower 95% CI               False      NON_INFERIORITY
# 4             NaN  lower 95% CI               False      NON_INFERIORITY
# ...           ...           ...                 ...                  ...
# 1037249  0.554490             ?               False                   NA
# 1037250  0.312255             ?               False                   NA
# 1037251  0.751883             ?               False                   NA
# 1037252  0.345805             ?               False                   NA
# 1037253  0.150784             ?               False                   NA
#
#                                    non_inferiority_comment  param_value  \
# 0                                                       NA     -0.00033
# 1                                                       NA      0.00100
# 2                                                       NA      0.00240
# 3        The null hypothesis is p-p0 ≤ -0.1. The altern...     -0.05000
# 4        The prespecified non inferiority margin was 20...      0.74000
# ...                                                    ...          ...
# 1037249                                                 NA          NaN
# 1037250                                                 NA          NaN
# 1037251                                                 NA          NaN
# 1037252                                                 NA          NaN
# 1037253                                                 NA          NaN
#
#          ci_pct  ci_lower  ci_upper          groups  \
# 0            95   -0.0020    0.0014         [OG000]
# 1            95   -0.0036    0.0056         [OG000]
# 2            95   -0.0030    0.0078         [OG000]
# 3            95   -0.0500       NaN  [OG000, OG001]
# 4            95    0.7400    0.9400  [OG000, OG001]
# ...         ...       ...       ...             ...
# 1037249      -1   -1.0000   -1.0000  [OG000, OG001]
# 1037250      -1   -1.0000   -1.0000  [OG000, OG001]
# 1037251      -1   -1.0000   -1.0000  [OG000, OG001]
# 1037252      -1   -1.0000   -1.0000  [OG000, OG001]
# 1037253      -1   -1.0000   -1.0000  [OG000, OG001]
#
#                                               group_titles       id
# 0                       {'OG000': 'Mycophenolate Mofetil'}        0
# 1                       {'OG000': 'Mycophenolate Mofetil'}        1
# 2                       {'OG000': 'Mycophenolate Mofetil'}        2
# 3        {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...        3
# 4        {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...        4
# ...                                                    ...      ...
# 1037249   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}  1037249
# 1037250   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}  1037250
# 1037251   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}  1037251
# 1037252   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}  1037252
# 1037253   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}  1037253
#
# [1037254 rows x 16 columns]

# %%
db_analytics.drop(columns=['groups', 'group_titles']).to_sql('analytics', db, index=False, if_exists='append')

# %% [markdown]
# ### Comparisons

# %%
db_analytics.head()
# Out:
#          study  measure  from_study                       method  p_value  \
# 0  NCT03262441        2        True                           NA      NaN
# 1  NCT03262441        3        True                           NA      NaN
# 2  NCT03262441        4        True                           NA      NaN
# 3  NCT03264157       32        True  Farrington and Manning test   0.0006
# 4  NCT03264157       33        True                           NA      NaN
#
#      param_type  is_non_inferiority non_inferiority_type  \
# 0         Slope               False                OTHER
# 1         Slope               False                OTHER
# 2         Slope               False                OTHER
# 3  lower 95% CI               False      NON_INFERIORITY
# 4  lower 95% CI               False      NON_INFERIORITY
#
#                              non_inferiority_comment  param_value  ci_pct  \
# 0                                                 NA     -0.00033      95
# 1                                                 NA      0.00100      95
# 2                                                 NA      0.00240      95
# 3  The null hypothesis is p-p0 ≤ -0.1. The altern...     -0.05000      95
# 4  The prespecified non inferiority margin was 20...      0.74000      95
#
#    ci_lower  ci_upper          groups  \
# 0   -0.0020    0.0014         [OG000]
# 1   -0.0036    0.0056         [OG000]
# 2   -0.0030    0.0078         [OG000]
# 3   -0.0500       NaN  [OG000, OG001]
# 4    0.7400    0.9400  [OG000, OG001]
#
#                                         group_titles  id
# 0                 {'OG000': 'Mycophenolate Mofetil'}   0
# 1                 {'OG000': 'Mycophenolate Mofetil'}   1
# 2                 {'OG000': 'Mycophenolate Mofetil'}   2
# 3  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...   3
# 4  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...   4

# %%
analytics_group = db_analytics[['id', 'group_titles', 'study']]

# %%
analytics_group['group_title'] = analytics_group['group_titles'].apply(lambda x: [(k,v) for k,v in x.items()])
# Out:
# <ipython-input-29-d9034fe79d69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analytics_group['group_title'] = analytics_group['group_titles'].apply(lambda x: [(k,v) for k,v in x.items()])

# %%
exploded = analytics_group.explode('group_title')

# %%
exploded['study_id'] = exploded['group_title'].apply(lambda x: x[0])

# %%
exploded['title'] = exploded['group_title'].apply(lambda x: x[1])

# %%
exploded
# Out:
#               id                                       group_titles  \
# 0              0                 {'OG000': 'Mycophenolate Mofetil'}
# 1              1                 {'OG000': 'Mycophenolate Mofetil'}
# 2              2                 {'OG000': 'Mycophenolate Mofetil'}
# 3              3  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...
# 3              3  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...
# ...          ...                                                ...
# 1037251  1037251   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 1037252  1037252   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 1037252  1037252   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 1037253  1037253   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 1037253  1037253   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
#
#                study                              group_title study_id  \
# 0        NCT03262441           (OG000, Mycophenolate Mofetil)    OG000
# 1        NCT03262441           (OG000, Mycophenolate Mofetil)    OG000
# 2        NCT03262441           (OG000, Mycophenolate Mofetil)    OG000
# 3        NCT03264157             (OG000, BPL HRIG + RabAvert)    OG000
# 3        NCT03264157  (OG001, Comparator HyperRab + RabAvert)    OG001
# ...              ...                                      ...      ...
# 1037251  NCT03031496                     (OG001, Treatment B)    OG001
# 1037252  NCT03031496                     (OG000, Treatment A)    OG000
# 1037252  NCT03031496                     (OG001, Treatment B)    OG001
# 1037253  NCT03031496                     (OG000, Treatment A)    OG000
# 1037253  NCT03031496                     (OG001, Treatment B)    OG001
#
#                                   title
# 0                 Mycophenolate Mofetil
# 1                 Mycophenolate Mofetil
# 2                 Mycophenolate Mofetil
# 3                   BPL HRIG + RabAvert
# 3        Comparator HyperRab + RabAvert
# ...                                 ...
# 1037251                     Treatment B
# 1037252                     Treatment A
# 1037252                     Treatment B
# 1037253                     Treatment A
# 1037253                     Treatment B
#
# [2068181 rows x 6 columns]

# %%
admin_merge = pd.read_csv('admins_join_groups.csv')
admin_merge.head()
# Out:
#       id  group  treatment                                        description  \
# 0  24766   1922        428  Participants in cohort 3 received once 1- to 4...
# 1  24184   1906       2516  2 subcutaneous injections of Dupilumab 300 mg ...
# 2  24185   1906        103  2 subcutaneous injections of Dupilumab 300 mg ...
# 3  24186   1906       2403  2 subcutaneous injections of Dupilumab 300 mg ...
# 4  24187   1906       2517  2 subcutaneous injections of Dupilumab 300 mg ...
#
#    id.1                       title study_id  \
# 0  1922  Cohort 3 Brexpiprazole 4mg    OG002
# 1  1906        Dupilumab 300 mg q4w    OG003
# 2  1906        Dupilumab 300 mg q4w    OG003
# 3  1906        Dupilumab 300 mg q4w    OG003
# 4  1906        Dupilumab 300 mg q4w    OG003
#
#                                        description.1        study
# 0  Participants in cohort 3 received 1- to 4-mg d...  NCT01854944
# 1  2 subcutaneous injections of Dupilumab 300 mg ...  NCT01854047
# 2  2 subcutaneous injections of Dupilumab 300 mg ...  NCT01854047
# 3  2 subcutaneous injections of Dupilumab 300 mg ...  NCT01854047
# 4  2 subcutaneous injections of Dupilumab 300 mg ...  NCT01854047

# %%
comp_table = admin_merge[['group', 'study_id', 'title', 'study']].drop_duplicates()
comp_table
# Out:
#         group study_id                                  title        study
# 0        1922    OG002             Cohort 3 Brexpiprazole 4mg  NCT01854944
# 1        1906    OG003                   Dupilumab 300 mg q4w  NCT01854047
# 6        1918    OG000          Cohort 1 - Brexpiprazole 4 mg  NCT01854944
# 8        1928    OG001                Mometasone Furoate 0.1%  NCT01856543
# 11       1932    OG001          SOF+VEL 100 mg 12 Weeks (GT1)  NCT01858766
# ...       ...      ...                                    ...          ...
# 215450   1879    OG001  Placebo to 100 mg q2w Due to EE/LE/CO  NCT01856309
# 215456   1871    OG000                            FPNS 200 μg  NCT01916226
# 215461   1889    OG001                                TPV/RBV  NCT01854528
# 215465   1894    OG002                          TXA-500 Group  NCT01850394
# 215467   1898    OG001                             Ticagrelor  NCT01852214
#
# [97909 rows x 4 columns]

# %%
comp_table[comp_table['title'] == 'Milnacipram']
# Out:
# Empty DataFrame
# Columns: [group, study_id, title, study]
# Index: []

# %%
merged = exploded.merge(comp_table, 'left', ['study_id', 'title', 'study'])

# %%
merged[merged['group'].isna()]
# Out:
#             id                                       group_titles  \
# 2572      1125                           {'OG000': 'Milnacipram'}
# 2574      1127                           {'OG000': 'Milnacipram'}
# 2575      1128                           {'OG000': 'Milnacipram'}
# 3208      1315                             {'OG000': 'Milciclib'}
# 29311    12449  {'OG000': 'Control: Losartan / Week 4,8 -ITT',...
# ...        ...                                                ...
# 310792  133315                             {'OG000': 'Treatment'}
# 310793  133316                             {'OG000': 'Treatment'}
# 310794  133317                             {'OG000': 'Treatment'}
# 310795  133318                             {'OG000': 'Treatment'}
# 325119  138981      {'OG000': 'Milciclib Maleate (PHA-848125AC)'}
#
#               study                                 group_title study_id  \
# 2572    NCT01304589                        (OG000, Milnacipram)    OG000
# 2574    NCT01304589                        (OG000, Milnacipram)    OG000
# 2575    NCT01304589                        (OG000, Milnacipram)    OG000
# 3208    NCT01301391                          (OG000, Milciclib)    OG000
# 29311   NCT00922480  (OG000, Control: Losartan / Week 4,8 -ITT)    OG000
# ...             ...                                         ...      ...
# 310792  NCT01288807                          (OG000, Treatment)    OG000
# 310793  NCT01288807                          (OG000, Treatment)    OG000
# 310794  NCT01288807                          (OG000, Treatment)    OG000
# 310795  NCT01288807                          (OG000, Treatment)    OG000
# 325119  NCT01011439   (OG000, Milciclib Maleate (PHA-848125AC))    OG000
#
#                                     title  group
# 2572                          Milnacipram    NaN
# 2574                          Milnacipram    NaN
# 2575                          Milnacipram    NaN
# 3208                            Milciclib    NaN
# 29311   Control: Losartan / Week 4,8 -ITT    NaN
# ...                                   ...    ...
# 310792                          Treatment    NaN
# 310793                          Treatment    NaN
# 310794                          Treatment    NaN
# 310795                          Treatment    NaN
# 325119   Milciclib Maleate (PHA-848125AC)    NaN
#
# [197 rows x 7 columns]

# %%
merged = merged[~merged['group'].isna()]

# %%
merged['group'] = merged['group'].apply(int)
# Out:
# <ipython-input-45-48ed87de68e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['group'] = merged['group'].apply(int)

# %%
merged
# Out:
#               id                                       group_titles  \
# 0              0                 {'OG000': 'Mycophenolate Mofetil'}
# 1              1                 {'OG000': 'Mycophenolate Mofetil'}
# 2              2                 {'OG000': 'Mycophenolate Mofetil'}
# 3              3  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...
# 4              3  {'OG000': 'BPL HRIG + RabAvert', 'OG001': 'Com...
# ...          ...                                                ...
# 2448666  1037251   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 2448667  1037252   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 2448668  1037252   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 2448669  1037253   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
# 2448670  1037253   {'OG000': 'Treatment A', 'OG001': 'Treatment B'}
#
#                study                     group_title study_id  \
# 0        NCT03262441  (OG000, Mycophenolate Mofetil)    OG000
# 1        NCT03262441  (OG000, Mycophenolate Mofetil)    OG000
# 2        NCT03262441  (OG000, Mycophenolate Mofetil)    OG000
# 3        NCT03264157    (OG000, BPL HRIG + RabAvert)    OG000
# 4        NCT03264157    (OG000, BPL HRIG + RabAvert)    OG000
# ...              ...                             ...      ...
# 2448666  NCT03031496            (OG001, Treatment B)    OG001
# 2448667  NCT03031496            (OG000, Treatment A)    OG000
# 2448668  NCT03031496            (OG001, Treatment B)    OG001
# 2448669  NCT03031496            (OG000, Treatment A)    OG000
# 2448670  NCT03031496            (OG001, Treatment B)    OG001
#
#                          title  group
# 0        Mycophenolate Mofetil  35420
# 1        Mycophenolate Mofetil  35420
# 2        Mycophenolate Mofetil  35420
# 3          BPL HRIG + RabAvert  35435
# 4          BPL HRIG + RabAvert  35433
# ...                        ...    ...
# 2448666            Treatment B  98186
# 2448667            Treatment A  98185
# 2448668            Treatment B  98186
# 2448669            Treatment A  98185
# 2448670            Treatment B  98186
#
# [2448474 rows x 7 columns]

# %%
db_comparisons = merged.rename(columns={
    'id': 'analytic',
})[['analytic', 'group']]

# %%
db_comparisons.to_sql('comparison', db, index=False, if_exists='append')

# %% [markdown]
# ### Baselines

# %%
baselines = pd.read_csv('db_int_baselines.csv')
# Out:
# /Users/porterhunley/opt/anaconda3/envs/mediboard/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
baselines
# Out:
#         Unnamed: 0                        base  \
# 0                3           Sex: Female, Male
# 1                4           Sex: Female, Male
# 2                5           Sex: Female, Male
# 3                6           Sex: Female, Male
# 4                7           Sex: Female, Male
# ...            ...                         ...
# 721813      849094        Region of Enrollment
# 721814      849095        Region of Enrollment
# 721815      849159  Race/Ethnicity, Customized
# 721816      849160  Race/Ethnicity, Customized
# 721817      849161  Race/Ethnicity, Customized
#
#                                       clss category             param_type  \
# 0                                      NaN   Female  Count of Participants
# 1                                      NaN   Female  Count of Participants
# 2                                      NaN   Female  Count of Participants
# 3                                      NaN     Male  Count of Participants
# 4                                      NaN     Male  Count of Participants
# ...                                    ...      ...                    ...
# 721813                       United States      NaN                 Number
# 721814                       United States      NaN                 Number
# 721815  Black or African American Heritage      NaN  Count of Participants
# 721816                      White Heritage      NaN  Count of Participants
# 721817                      Mixed Heritage      NaN  Count of Participants
#
#        dispersion          unit  value  spread  upper  lower    type sub_type  \
# 0             NaN  Participants   16.0     NaN    NaN    NaN  GENDER   FEMALE
# 1             NaN  Participants   16.0     NaN    NaN    NaN  GENDER   FEMALE
# 2             NaN  Participants   32.0     NaN    NaN    NaN  GENDER   FEMALE
# 3             NaN  Participants   35.0     NaN    NaN    NaN  GENDER     MALE
# 4             NaN  Participants   33.0     NaN    NaN    NaN  GENDER     MALE
# ...           ...           ...    ...     ...    ...    ...     ...      ...
# 721813        NaN  participants   29.0     NaN    NaN    NaN   OTHER      NaN
# 721814        NaN  participants   50.0     NaN    NaN    NaN   OTHER      NaN
# 721815        NaN  Participants   29.0     NaN    NaN    NaN   OTHER      NaN
# 721816        NaN  Participants   12.0     NaN    NaN    NaN    RACE    WHITE
# 721817        NaN  Participants    1.0     NaN    NaN    NaN   OTHER      NaN
#
#               study  group
# 0       NCT03266419  BG000
# 1       NCT03266419  BG001
# 2       NCT03266419  BG002
# 3       NCT03266419  BG000
# 4       NCT03266419  BG001
# ...             ...    ...
# 721813  NCT03030989  BG001
# 721814  NCT03030989  BG002
# 721815  NCT03031496  BG000
# 721816  NCT03031496  BG000
# 721817  NCT03031496  BG000
#
# [721818 rows x 15 columns]

# %%
baselines['base'] = baselines['base'].fillna('NA')
baselines['clss'] = baselines['clss'].fillna('NA')
baselines['category'] = baselines['category'].fillna('NA')
baselines['param_type'] = baselines['param_type'].fillna('NA')
baselines['unit'] = baselines['unit'].fillna('NA')
baselines['type'] = baselines['type'].fillna('OTHER')
baselines['sub_type'] = baselines['sub_type'].fillna('NA')

# %%
baselines = baselines.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-80e0473e3dcb> in <module>
# ----> 1 baselines = baselines.drop(columns=['Unnamed: 0'])
#       2 baselines = baselines.drop(columns=['group'])
#
# ~/opt/anaconda3/envs/mediboard/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/envs/mediboard/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/opt/anaconda3/envs/mediboard/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/opt/anaconda3/envs/mediboard/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
baselines = baselines.drop(columns=['group'])

# %%
baselines['param_type'] = baselines['param_type'].str.upper().str.replace(' ', '_')

# %%
baselines['dispersion'] = baselines['dispersion'].str.replace(' ','_').str.replace('-','_')

# %%
baselines['category'].str.len().max()
# Out:
# 94

# %%
baselines.to_sql('baselines', db, index=False, if_exists='append')

# %% [markdown]
# ### Effects Groups

# %%
effect_groups = pd.read_pickle('effects_groups_treats.pkl')
effect_groups
# Out:
#           study_id group_id                          title  \
# 0      NCT03266419    EG000      Deep NMB Using Rocuronium
# 1      NCT03266419    EG001  Moderate NMB Using Rocuronium
# 2      NCT03262441    EG000          Mycophenolate Mofetil
# 3      NCT03260894    EG000    Pembrolizumab + Epacadostat
# 4      NCT03260894    EG001   SoC (Sunitinib or Pazopanib)
# ...            ...      ...                            ...
# 68808  NCT03038880    EG000            6 mg Faricimab Q12W
# 68809  NCT03038880    EG001            6 mg Faricimab Q16W
# 68810  NCT03038880    EG002         0.5 mg Ranibizumab Q4W
# 68811  NCT03031496    EG000                    Treatment A
# 68812  NCT03031496    EG001                    Treatment B
#
#                                              description  \
# 0      The abdomen is insufflated to 13 mmHg pneumope...
# 1      The abdomen is insufflated to 13 mmHg pneumope...
# 2      Mycophenolate Mofetil 500mg Tablets once per d...
# 3      Pembrolizumab 200 mg administered intravenousl...
# 4      Standard of care (SoC) (sunitinib or pazopanib...
# ...                                                  ...
# 68808  6 mg faricimab was given by intravitreal (IVT)...
# 68809  6 mg faricimab was administered by IVT injecti...
# 68810  0.5 mg of ranibizumab was administered by IVT ...
# 68811  Participants received a single oral dose of hy...
# 68812  Participants received a single oral dose of hy...
#
#                                          desc_plus_title  \
# 0      Deep NMB Using Rocuronium The abdomen is insuf...
# 1      Moderate NMB Using Rocuronium The abdomen is i...
# 2      Mycophenolate Mofetil Mycophenolate Mofetil 50...
# 3      Pembrolizumab + Epacadostat Pembrolizumab 200 ...
# 4      SoC (Sunitinib or Pazopanib) Standard of care ...
# ...                                                  ...
# 68808  6 mg Faricimab Q12W 6 mg faricimab was given b...
# 68809  6 mg Faricimab Q16W 6 mg faricimab was adminis...
# 68810  0.5 mg Ranibizumab Q4W 0.5 mg of ranibizumab w...
# 68811  Treatment A Participants received a single ora...
# 68812  Treatment B Participants received a single ora...
#
#                                               treatments  \
# 0                                           [rocuronium]
# 1                                           [rocuronium]
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...
# 3                                          [epacadostat]
# 4                                 [pazopanib, sunitinib]
# ...                                                  ...
# 68808                                        [faricimab]
# 68809                      [no, faricimabivt, faricimab]
# 68810                                                 []
# 68811      [hydrochlorothiazide, amiloridehydrochloride]
# 68812      [hydrochlorothiazide, amiloridehydrochloride]
#
#                                                 adjusted
# 0                                           [rocuronium]
# 1                                           [rocuronium]
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...
# 3                                          [epacadostat]
# 4                                 [pazopanib, sunitinib]
# ...                                                  ...
# 68808                                        [faricimab]
# 68809                      [no, faricimabivt, faricimab]
# 68810                                                 []
# 68811      [hydrochlorothiazide, amiloridehydrochloride]
# 68812      [hydrochlorothiazide, amiloridehydrochloride]
#
# [68813 rows x 7 columns]

# %%
def is_str_double(string):
    return string[:len(string)//2] == string[len(string)//2:]

# %%
# We will just use the raw treatments column for now - maybe we sould do some cleaning of the treatments in the future
# Append these to treatments if they don't exist

db_treats = pd.read_csv('meditreats_public_treatments.csv')

# %%
treats = set(db_treats['name'].unique())

# %%
effects_treats = effect_groups.explode('treatments')

# %%
effects_treats = effects_treats[~effects_treats['treatments'].isna()]['treatments'].str.capitalize().apply(lambda x: x[:len(x)//2] if is_str_double(x) else x)

# %%
new_effects_treats = [x for x in effects_treats if x not in treats]

# %%
new_treats = pd.Series(list(set(new_effects_treats)))
# Out:
# <ipython-input-16-0411196b041c>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   new_treats = pd.Series(list(set(new_effects_treats)))

# %%
new_db_treats = pd.DataFrame.from_dict({
    'name': new_treats.to_list(),
    'from_study': [False for x in range(len(new_treats))],
    'no_studies': [-1 for x in range(len(new_treats))]
                })

# %%
pd.Series(new_db_treats.index + 1)
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 10622    10623
# 10623    10624
# 10624    10625
# 10625    10626
# 10626    10627
# Length: 10627, dtype: int64

# %%
new_db_treats['id'] = pd.Series(new_db_treats.index+11818)

# %%
new_db_treats.to_sql('treatments', db, index=False, if_exists='append')

# %%
new_db_treats
# Out:
#                       name  from_study  no_studies     id
# 0     Raltegravirtenofovir       False          -1  11818
# 1            Coprecipitate       False          -1  11819
# 2         Poly(adp-ribose)       False          -1  11820
# 3        Darbepoetinalfana       False          -1  11821
# 4            Propranololla       False          -1  11822
# ...                    ...         ...         ...    ...
# 1836              Svn53-67       False          -1  13654
# 1837                Benzyl       False          -1  13655
# 1838                  Nf54       False          -1  13656
# 1839           Treosulfane       False          -1  13657
# 1840                   Dga       False          -1  13658
#
# [1841 rows x 4 columns]

# %%
# Load back the treatments and merge them with the groups
db_treats = pd.read_csv('meditreats_public_treatments.csv')

# %%
db_treats
# Out:
#           id              name  from_study  no_studies
# 0          0  Cyclophosphamide        True         678
# 1          1          Vaccines        True         644
# 2          2        Paclitaxel        True         621
# 3          3       Bevacizumab        True         607
# 4          4     Dexamethasone        True         542
# ...      ...               ...         ...         ...
# 13653  13654          Svn53-67       False          -1
# 13654  13655            Benzyl       False          -1
# 13655  13656              Nf54       False          -1
# 13656  13657       Treosulfane       False          -1
# 13657  13658               Dga       False          -1
#
# [13658 rows x 4 columns]

# %%
# Upload the groups to get the id then we can merge
effect_groups['id'] = effect_groups.index

# %%
effect_groups
# Out:
#           study_id group_id                          title  \
# 0      NCT03266419    EG000      Deep NMB Using Rocuronium
# 1      NCT03266419    EG001  Moderate NMB Using Rocuronium
# 2      NCT03262441    EG000          Mycophenolate Mofetil
# 3      NCT03260894    EG000    Pembrolizumab + Epacadostat
# 4      NCT03260894    EG001   SoC (Sunitinib or Pazopanib)
# ...            ...      ...                            ...
# 68808  NCT03038880    EG000            6 mg Faricimab Q12W
# 68809  NCT03038880    EG001            6 mg Faricimab Q16W
# 68810  NCT03038880    EG002         0.5 mg Ranibizumab Q4W
# 68811  NCT03031496    EG000                    Treatment A
# 68812  NCT03031496    EG001                    Treatment B
#
#                                              description  \
# 0      The abdomen is insufflated to 13 mmHg pneumope...
# 1      The abdomen is insufflated to 13 mmHg pneumope...
# 2      Mycophenolate Mofetil 500mg Tablets once per d...
# 3      Pembrolizumab 200 mg administered intravenousl...
# 4      Standard of care (SoC) (sunitinib or pazopanib...
# ...                                                  ...
# 68808  6 mg faricimab was given by intravitreal (IVT)...
# 68809  6 mg faricimab was administered by IVT injecti...
# 68810  0.5 mg of ranibizumab was administered by IVT ...
# 68811  Participants received a single oral dose of hy...
# 68812  Participants received a single oral dose of hy...
#
#                                          desc_plus_title  \
# 0      Deep NMB Using Rocuronium The abdomen is insuf...
# 1      Moderate NMB Using Rocuronium The abdomen is i...
# 2      Mycophenolate Mofetil Mycophenolate Mofetil 50...
# 3      Pembrolizumab + Epacadostat Pembrolizumab 200 ...
# 4      SoC (Sunitinib or Pazopanib) Standard of care ...
# ...                                                  ...
# 68808  6 mg Faricimab Q12W 6 mg faricimab was given b...
# 68809  6 mg Faricimab Q16W 6 mg faricimab was adminis...
# 68810  0.5 mg Ranibizumab Q4W 0.5 mg of ranibizumab w...
# 68811  Treatment A Participants received a single ora...
# 68812  Treatment B Participants received a single ora...
#
#                                               treatments  \
# 0                                           [rocuronium]
# 1                                           [rocuronium]
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...
# 3                                          [epacadostat]
# 4                                 [pazopanib, sunitinib]
# ...                                                  ...
# 68808                                        [faricimab]
# 68809                      [no, faricimabivt, faricimab]
# 68810                                                 []
# 68811      [hydrochlorothiazide, amiloridehydrochloride]
# 68812      [hydrochlorothiazide, amiloridehydrochloride]
#
#                                                 adjusted     id
# 0                                           [rocuronium]      0
# 1                                           [rocuronium]      1
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...      2
# 3                                          [epacadostat]      3
# 4                                 [pazopanib, sunitinib]      4
# ...                                                  ...    ...
# 68808                                        [faricimab]  68808
# 68809                      [no, faricimabivt, faricimab]  68809
# 68810                                                 []  68810
# 68811      [hydrochlorothiazide, amiloridehydrochloride]  68811
# 68812      [hydrochlorothiazide, amiloridehydrochloride]  68812
#
# [68813 rows x 8 columns]

# %%
effect_groups.rename(columns={
    'study_id': 'study',
    'group_id': 'study_id'
})[['id', 'title', 'description', 'study_id']].to_sql('effectsgroups', db, index=False, if_exists='append')

# %% [markdown]
# ### Effects

# %%
effects_0 = pd.read_pickle('int_newer_effects_0.pkl')
effects_1 = pd.read_pickle('int_newer_effects_1.pkl')
effects_2 = pd.read_pickle('int_newer_effects_2.pkl')

effects = pd.concat([effects_0, effects_1, effects_0]).reset_index(drop=True)

# %%
effects
# Out:
#             study_id group_id            effect_name     type  \
# 0        NCT03262441    EG000      Finger cellulitis  serious
# 1        NCT03260894    EG000                Anaemia    other
# 2        NCT03260894    EG001                Anaemia    other
# 3        NCT03260894    EG000       Thrombocytopenia    other
# 4        NCT03260894    EG001       Thrombocytopenia    other
# ...              ...      ...                    ...      ...
# 4865148  NCT00265148    EG001  MYOCARDIAL INFARCTION  serious
# 4865149  NCT00265148    EG000          HYPONATRAEMIA  serious
# 4865150  NCT00265148    EG001          HYPONATRAEMIA  serious
# 4865151  NCT00265148    EG000     ABNORMAL BEHAVIOUR  serious
# 4865152  NCT00265148    EG001     ABNORMAL BEHAVIOUR  serious
#
#                                    organ_system              assesment  \
# 0        Skin and subcutaneous tissue disorders  Systematic Assessment
# 1          Blood and lymphatic system disorders  Systematic Assessment
# 2          Blood and lymphatic system disorders  Systematic Assessment
# 3          Blood and lymphatic system disorders  Systematic Assessment
# 4          Blood and lymphatic system disorders  Systematic Assessment
# ...                                         ...                    ...
# 4865148                       Cardiac disorders  Systematic Assessment
# 4865149      Metabolism and nutrition disorders  Systematic Assessment
# 4865150      Metabolism and nutrition disorders  Systematic Assessment
# 4865151                   Psychiatric disorders  Systematic Assessment
# 4865152                   Psychiatric disorders  Systematic Assessment
#
#          no_effected  collection_threshold  no_at_risk
# 0                1.0                   0.0           5
# 1               10.0                   5.0          64
# 2               12.0                   5.0          63
# 3                2.0                   5.0          64
# 4                4.0                   5.0          63
# ...              ...                   ...         ...
# 4865148          0.0                   5.0          40
# 4865149          1.0                   5.0          40
# 4865150          0.0                   5.0          40
# 4865151          0.0                   5.0          40
# 4865152          1.0                   5.0          40
#
# [4865153 rows x 9 columns]

# %%
# Get DB effect groups 
db_effect_groups = pd.read_csv('effects_groups_study.csv')

# %%
db_effect_groups
# Out:
#              study     id study_id
# 0      NCT00000125  46463    EG000
# 1      NCT00000125  46464    EG001
# 2      NCT00000134  46556    EG000
# 3      NCT00000134  46557    EG001
# 4      NCT00000134  46558    EG002
# ...            ...    ...      ...
# 43234  NCT04534465  15977    EG004
# 43235  NCT04534491  15978    EG000
# 43236  NCT04555525   5662    EG000
# 43237  NCT04555525   5663    EG001
# 43238  NCT04578496   5906    EG000
#
# [43239 rows x 3 columns]

# %%
# Merge in the groups
db_effects = effects.merge(db_effect_groups.rename(columns={
    'study_id': 'group_id',
    'study': 'study_id'
})).rename(columns= {
    'id': 'group',
    'study_id': 'study',
    'effect_name': 'name'
})

# %%
len(db_effects)
# Out:
# 4865153

# %%
db_effects = db_effects.drop_duplicates(['study','group','name','no_at_risk'])

# %%
# We need to make a bunch of new tables for this to work :(
db_effects['type'].value_counts()
# Out:
# other      1878977
# serious    1180731
# Name: type, dtype: int64

# %%
db_effects
# Out:
#                study group_id                     name     type  \
# 0        NCT03262441    EG000        Finger cellulitis  serious
# 2        NCT03260894    EG000                  Anaemia    other
# 3        NCT03260894    EG000         Thrombocytopenia    other
# 4        NCT03260894    EG000          Hyperthyroidism    other
# 5        NCT03260894    EG000           Hypothyroidism    other
# ...              ...      ...                      ...      ...
# 4865146  NCT03496974    EG001   Swelling on right hand    other
# 4865147  NCT03496974    EG001  Urinary Track Infection    other
# 4865148  NCT03496974    EG001                 Vomiting    other
# 4865149  NCT03496974    EG001                 Wheezing    other
# 4865151  NCT03496974    EG001   worsening hypertension    other
#
#                                             organ_system  \
# 0                 Skin and subcutaneous tissue disorders
# 2                   Blood and lymphatic system disorders
# 3                   Blood and lymphatic system disorders
# 4                                    Endocrine disorders
# 5                                    Endocrine disorders
# ...                                                  ...
# 4865146                                General disorders
# 4865147                      Infections and infestations
# 4865148                       Gastrointestinal disorders
# 4865149  Respiratory, thoracic and mediastinal disorders
# 4865151                                Cardiac disorders
#
#                      assesment  no_effected  collection_threshold  no_at_risk  \
# 0        Systematic Assessment          1.0                   0.0           5
# 2        Systematic Assessment         10.0                   5.0          64
# 3        Systematic Assessment          2.0                   5.0          64
# 4        Systematic Assessment          5.0                   5.0          64
# 5        Systematic Assessment          9.0                   5.0          64
# ...                        ...          ...                   ...         ...
# 4865146  Systematic Assessment          1.0                   0.0          28
# 4865147  Systematic Assessment          1.0                   0.0          28
# 4865148  Systematic Assessment          1.0                   0.0          28
# 4865149  Systematic Assessment          2.0                   0.0          28
# 4865151  Systematic Assessment          0.0                   0.0          28
#
#          group
# 0            2
# 2            3
# 3            3
# 4            3
# 5            3
# ...        ...
# 4865146  49099
# 4865147  49099
# 4865148  49099
# 4865149  49099
# 4865151  49099
#
# [3059708 rows x 10 columns]

# %%
db_effects['type'] = db_effects['type'].str.upper()
# Out:
# <ipython-input-14-0c1a9915091d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_effects['type'] = db_effects['type'].str.upper()

# %%
db_effects['organ_system'] = db_effects['organ_system'].apply(str)
# Out:
# <ipython-input-15-2148f3331e9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_effects['organ_system'] = db_effects['organ_system'].apply(str)

# %%
db_effects['organ_system'] = db_effects['organ_system'].apply(lambda x: x.split(' (')[0])
# Out:
# <ipython-input-16-c22cae0f5673>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_effects['organ_system'] = db_effects['organ_system'].apply(lambda x: x.split(' (')[0])

# %%
db_effects['organ_system'] = db_effects['organ_system'].str.upper().str.replace(' ','_').str.replace(',','')
# Out:
# <ipython-input-17-e97228936e87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_effects['organ_system'] = db_effects['organ_system'].str.upper().str.replace(' ','_').str.replace(',','')

# %%
db_effects['assesment'] = db_effects['assesment'].str.upper().str.replace(' ','_').str.replace('-','_')
# Out:
# <ipython-input-18-ff24b85ab943>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_effects['assesment'] = db_effects['assesment'].str.upper().str.replace(' ','_').str.replace('-','_')

# %%
db_effects['id'] = db_effects.index
# Out:
# <ipython-input-19-816740fc377e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_effects['id'] = db_effects.index

# %%
db_effects = db_effects.rename(columns={
    'type': 'effect_type',
    'assesment': 'assessment'
})

# %%
db_effects
# Out:
#                study group_id                     name effect_type  \
# 0        NCT03262441    EG000        Finger cellulitis     SERIOUS
# 2        NCT03260894    EG000                  Anaemia       OTHER
# 3        NCT03260894    EG000         Thrombocytopenia       OTHER
# 4        NCT03260894    EG000          Hyperthyroidism       OTHER
# 5        NCT03260894    EG000           Hypothyroidism       OTHER
# ...              ...      ...                      ...         ...
# 4865146  NCT03496974    EG001   Swelling on right hand       OTHER
# 4865147  NCT03496974    EG001  Urinary Track Infection       OTHER
# 4865148  NCT03496974    EG001                 Vomiting       OTHER
# 4865149  NCT03496974    EG001                 Wheezing       OTHER
# 4865151  NCT03496974    EG001   worsening hypertension       OTHER
#
#                                            organ_system  \
# 0                SKIN_AND_SUBCUTANEOUS_TISSUE_DISORDERS
# 2                  BLOOD_AND_LYMPHATIC_SYSTEM_DISORDERS
# 3                  BLOOD_AND_LYMPHATIC_SYSTEM_DISORDERS
# 4                                   ENDOCRINE_DISORDERS
# 5                                   ENDOCRINE_DISORDERS
# ...                                                 ...
# 4865146                               GENERAL_DISORDERS
# 4865147                     INFECTIONS_AND_INFESTATIONS
# 4865148                      GASTROINTESTINAL_DISORDERS
# 4865149  RESPIRATORY_THORACIC_AND_MEDIASTINAL_DISORDERS
# 4865151                               CARDIAC_DISORDERS
#
#                     assessment  no_effected  collection_threshold  no_at_risk  \
# 0        SYSTEMATIC_ASSESSMENT          1.0                   0.0           5
# 2        SYSTEMATIC_ASSESSMENT         10.0                   5.0          64
# 3        SYSTEMATIC_ASSESSMENT          2.0                   5.0          64
# 4        SYSTEMATIC_ASSESSMENT          5.0                   5.0          64
# 5        SYSTEMATIC_ASSESSMENT          9.0                   5.0          64
# ...                        ...          ...                   ...         ...
# 4865146  SYSTEMATIC_ASSESSMENT          1.0                   0.0          28
# 4865147  SYSTEMATIC_ASSESSMENT          1.0                   0.0          28
# 4865148  SYSTEMATIC_ASSESSMENT          1.0                   0.0          28
# 4865149  SYSTEMATIC_ASSESSMENT          2.0                   0.0          28
# 4865151  SYSTEMATIC_ASSESSMENT          0.0                   0.0          28
#
#          group       id
# 0            2        0
# 2            3        2
# 3            3        3
# 4            3        4
# 5            3        5
# ...        ...      ...
# 4865146  49099  4865146
# 4865147  49099  4865147
# 4865148  49099  4865148
# 4865149  49099  4865149
# 4865151  49099  4865151
#
# [3059708 rows x 11 columns]

# %%
db_effects.drop(columns=['group_id']).to_sql('effects', db, index=False, if_exists='append')

# %% [markdown]
# ### Effects Comparisons

# %%
db_treats = pd.read_csv('meditreats_public_treatments.csv')

# %%
treats_merge = db_treats.rename(columns={
    'name': 'treatment'
})

# %%
db_treats.head()
# Out:
#    id              name  from_study  no_studies
# 0   0  Cyclophosphamide        True         678
# 1   1          Vaccines        True         644
# 2   2        Paclitaxel        True         621
# 3   3       Bevacizumab        True         607
# 4   4     Dexamethasone        True         542

# %%
treats_merge
# Out:
#           id         treatment  from_study  no_studies
# 0          0  Cyclophosphamide        True         678
# 1          1          Vaccines        True         644
# 2          2        Paclitaxel        True         621
# 3          3       Bevacizumab        True         607
# 4          4     Dexamethasone        True         542
# ...      ...               ...         ...         ...
# 13653  13654          Svn53-67       False          -1
# 13654  13655            Benzyl       False          -1
# 13655  13656              Nf54       False          -1
# 13656  13657       Treosulfane       False          -1
# 13657  13658               Dga       False          -1
#
# [13658 rows x 4 columns]

# %%
effect_groups_expl = effect_groups.explode('treatments')

# %%
effect_groups_expl['treatments'] = effect_groups_expl['treatments'].fillna('NA').str.capitalize()

# %%
effect_groups_expl
# Out:
#           study_id group_id                          title  \
# 0      NCT03266419    EG000      Deep NMB Using Rocuronium
# 1      NCT03266419    EG001  Moderate NMB Using Rocuronium
# 2      NCT03262441    EG000          Mycophenolate Mofetil
# 2      NCT03262441    EG000          Mycophenolate Mofetil
# 2      NCT03262441    EG000          Mycophenolate Mofetil
# ...            ...      ...                            ...
# 68810  NCT03038880    EG002         0.5 mg Ranibizumab Q4W
# 68811  NCT03031496    EG000                    Treatment A
# 68811  NCT03031496    EG000                    Treatment A
# 68812  NCT03031496    EG001                    Treatment B
# 68812  NCT03031496    EG001                    Treatment B
#
#                                              description  \
# 0      The abdomen is insufflated to 13 mmHg pneumope...
# 1      The abdomen is insufflated to 13 mmHg pneumope...
# 2      Mycophenolate Mofetil 500mg Tablets once per d...
# 2      Mycophenolate Mofetil 500mg Tablets once per d...
# 2      Mycophenolate Mofetil 500mg Tablets once per d...
# ...                                                  ...
# 68810  0.5 mg of ranibizumab was administered by IVT ...
# 68811  Participants received a single oral dose of hy...
# 68811  Participants received a single oral dose of hy...
# 68812  Participants received a single oral dose of hy...
# 68812  Participants received a single oral dose of hy...
#
#                                          desc_plus_title  \
# 0      Deep NMB Using Rocuronium The abdomen is insuf...
# 1      Moderate NMB Using Rocuronium The abdomen is i...
# 2      Mycophenolate Mofetil Mycophenolate Mofetil 50...
# 2      Mycophenolate Mofetil Mycophenolate Mofetil 50...
# 2      Mycophenolate Mofetil Mycophenolate Mofetil 50...
# ...                                                  ...
# 68810  0.5 mg Ranibizumab Q4W 0.5 mg of ranibizumab w...
# 68811  Treatment A Participants received a single ora...
# 68811  Treatment A Participants received a single ora...
# 68812  Treatment B Participants received a single ora...
# 68812  Treatment B Participants received a single ora...
#
#                                      treatments  \
# 0                                    Rocuronium
# 1                                    Rocuronium
# 2      Mycophenolatemofetilmycophenolatemofetil
# 2                     Mycophenolatemofetil500mg
# 2                          Mycophenolatemofetil
# ...                                         ...
# 68810                                        Na
# 68811                       Hydrochlorothiazide
# 68811                    Amiloridehydrochloride
# 68812                       Hydrochlorothiazide
# 68812                    Amiloridehydrochloride
#
#                                                 adjusted     id  \
# 0                                           [rocuronium]      0
# 1                                           [rocuronium]      1
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...      2
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...      2
# 2      [mycophenolatemofetilmycophenolatemofetil, myc...      2
# ...                                                  ...    ...
# 68810                                                 []  68810
# 68811      [hydrochlorothiazide, amiloridehydrochloride]  68811
# 68811      [hydrochlorothiazide, amiloridehydrochloride]  68811
# 68812      [hydrochlorothiazide, amiloridehydrochloride]  68812
# 68812      [hydrochlorothiazide, amiloridehydrochloride]  68812
#
#                                       treaments
# 0                                    Rocuronium
# 1                                    Rocuronium
# 2      Mycophenolatemofetilmycophenolatemofetil
# 2                     Mycophenolatemofetil500mg
# 2                          Mycophenolatemofetil
# ...                                         ...
# 68810                                        Na
# 68811                       Hydrochlorothiazide
# 68811                    Amiloridehydrochloride
# 68812                       Hydrochlorothiazide
# 68812                    Amiloridehydrochloride
#
# [122023 rows x 9 columns]

# %%
db_admins = effect_groups_expl[['id','treatments']].merge(db_treats[['name','id']], left_on='treatments', right_on='name')

# %%
db_admins.rename(columns={
    'id_x': 'group',
    'id_y': 'treatment'
})[['group', 'treatment']].to_sql('effectsadministrations', db, index=False, if_exists='append')
